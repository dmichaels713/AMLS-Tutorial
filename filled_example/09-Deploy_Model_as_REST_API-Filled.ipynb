# %% [markdown]
# # Deploy Model with either ACI or AKS
# Now it's time to deploy your model.  There are many ways to deploy models in Azure.  For testing purposes, we recommend Azure Container Instance (ACI).  For production purposes, we recommend Azure Kubernetes Service (AKS).  AKS requires a cluster to run on, but has much more robust security options and can run inside of a virtual network.<br>
#
# Both AKS and ACI are used for real-time or near real-time scoring situations.  These are situations where you want to send data to the system and immediately get a result to use in some process.
#
# To learn more about deployment, click here: https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-and-where

# %%
# Load Azure Libaries
from azureml.core import Datastore
from azureml.core.dataset import Dataset
from azureml.core.workspace import Workspace
from azureml.core.authentication import InteractiveLoginAuthentication
from azure.storage.blob import BlockBlobService
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.train.automl import AutoMLConfig
from azureml.core.experiment import Experiment
from azureml.core.environment import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.automl.core.featurization import FeaturizationConfig
from azureml.explain.model._internal.explanation_client import ExplanationClient

#Load Libraries for Deployment
from azureml.core.model import Model
from azureml.core.webservice import Webservice
from azureml.core.model import InferenceConfig
from azureml.core.webservice import AciWebservice
from azureml.core.webservice import AksWebservice
from azureml.core.compute import AksCompute, ComputeTarget

# Import other Libraries
import pandas as pd
import numpy as np
import logging
import requests
import json
import os
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Retrieve your workspace by name by filling in the lower case values between double quotes
ws = Workspace.get(name="ancient-rivers-ml-workspace",
        subscription_id="47a7ec0c-37ad-428b-9114-b87ea1057632",
        resource_group="xeek-ancient-rivers")

# %%
# Retrieve your Datastore by name by filling in the lower case values between double quotes
datastore_name = "ancientrivers"
datastore = Datastore.get(ws, datastore_name)

# %%
# Retrieve your Datasets by name by filling in the lower case values between double quotes
dataset_name_test  = "ancient-rivers-test-transformed"
dataset_name_train = "ancient-rivers-train-transformed"

# Load Data in as Tabular Datasets
testing_data  = Dataset.get_by_name(ws, dataset_name_test, version='latest')
training_data = Dataset.get_by_name(ws, dataset_name_train, version='latest')

# %%
# Convert your tabular dataset to pandas data frames
testTransformedDF = testing_data.to_pandas_dataframe()
trainTransformedDF = training_data.to_pandas_dataframe()

# %% [markdown]
# ### Now, deploy your model to your ACI Cluster.
# To deploy your model, you will need to use an entry script and an environment file.<br>
# ACI is for testing and has less security, less power and shorter timeouts than AKS.

# %%
# Retrieve your AutoML generated entry script
entry_script = 'inference/score.py'

# Retrieve your AutoML generated environment
environment = Environment.get(ws, 'automl-environment')

# Retrieve your AutoML Model
model = Model(ws, 'AutoML37a31f86512')

# %%
# Give your ACI deployment a name
aci_service_name = 'automl-ancient-rivers-aci'

# Set your scoring script and environment file
inference_config = InferenceConfig(entry_script=entry_script, environment = environment)

# Set your ACI configuration options
aci_config = AciWebservice.deploy_configuration(cpu_cores = 1, 
                                               memory_gb = 1, 
                                               tags = {'Project': 'Ancient Rivers', 'Type': 'Classification'}, 
                                               description = 'Ancient Rivers Deployment')

# Deploy your model to ACI
print(aci_service_name)
aci_service = Model.deploy(ws, aci_service_name, [model], inference_config, aci_config,overwrite=True)
aci_service.wait_for_deployment(True)
print(aci_service.state)
# Out:
# automl-ancient-rivers-aci
# Running......................................
# Succeeded
# ACI service creation operation finished, operation "Succeeded"
# Healthy

# %% [markdown]
# ### Create an AKS Cluster
# Select a VM Size and number of VMs to run your AKS cluster.  Your cores must number at least 12, so if you select a VM with 4 cores, set agent count to 3.<br>
# A single AKS Cluster can support many deployments depending on the size of the cluster.
#
# Check out AKS configuration options here:<br> https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.compute.aks.aksprovisioningconfiguration?view=azure-ml-py

# %%
from azureml.core.compute import AksCompute, ComputeTarget

# Run this cell only once.
# Set the configurations here.  Select Larger VM sizes and more agents for faster performance
prov_config = AksCompute.provisioning_configuration(vm_size='Standard_D3_v2', agent_count=3)
# Give your AKS Cluster a name
aks_name = 'dms-aks-cluster'
# Create the cluster and attach it to your workspace
aks_target = ComputeTarget.create(workspace = ws,
                                    name = aks_name,
                                    provisioning_configuration = prov_config)

# Wait for the create process to complete
aks_target.wait_for_completion(show_output = True)

# You only need to run this cell once to set up your AKS Cluster.
# After setting it up once, hashtag this cell out unless you want to create more clusters.
# Out:
# Creating..........................................................................................................................................................
# SucceededProvisioning operation finished, operation "Succeeded"

# %% [markdown]
# ### Deploy your model to your AKS Cluster.
# To deploy your model, you will need to use an entry script and an environment file.<br>
# AKS is for production jobs and can be configured to use large VMs, more security and longer timeouts than ACI.

# %%
# Retrieve your AutoML generated entry script
entry_script = 'inference/score.py'

# Retrieve your AutoML generated environment
environment = Environment.get(ws, 'automl-environment')

# Retrieve your AutoML Model
model = Model(ws, 'AutoML37a31f86512')

# %%
# Set your target AKS Cluster
aks_target = AksCompute(ws,'dms-aks-cluster')

# Give your deployment a name
aks_service_name = 'automl-ancient-rivers-aks'

# Set your scoring script and environment file
inference_config = InferenceConfig(entry_script=entry_script, environment = environment)

# Set your AKS configuration options
aks_config = AksWebservice.deploy_configuration(cpu_cores = 1, 
                                                memory_gb = 1, 
                                                tags = {'Project': 'Ancient Rivers', 'Type': 'Classification'}, 
                                                description = 'Ancient Rivers Deployment')

# Deploy your model to AKS
print(aks_service_name)
aks_service = Model.deploy(ws, aks_service_name, [model], inference_config, aks_config, aks_target,overwrite=True)
aks_service.wait_for_deployment(show_output = True)
print(aks_service.state)
# Out:
# automl-ancient-rivers-aks
# Running..........................
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
# Healthy

# %% [markdown]
# # Test your Deployment
# Test your AKS and ACI deployed models through your Jupyter Notebook.  You can also use CURL (Postman).

# %%
# Drop columns that are not used in your scoring script
# Create a sample to display the data easily

testSampleDF = testTransformedDF[(testTransformedDF.WellID == 5001)]
testScoreDF = testSampleDF.drop(['WellID'],axis=1)

# %%
# Use orient records to create your JSON file.  Other formats may not work.
# Preface your autoML test data with {"data": and close it with }

testJsonLoad = '{"data":' + testScoreDF.to_json(orient='records') + '}'

# %%
# Load the data into JSON 
testJson = json.loads(testJsonLoad)

# Convert your test data to a JSON string
input_data = json.dumps(testJson)

# %% [markdown]
# ### Examine your Scoring Script
# Make sure that you only include variables in your test data that appear in your scoring script's inference schema.<br>  Print out your script using the cell below and compare your schema with the print statement 2 cells down.

# %%
#Make variables to identify where your scoring file and folders are kept
scripts_folder = "inference"
script_file = "score.py"

# peek at contents
with open(os.path.join(scripts_folder, script_file)) as inference_file:
    print(inference_file.read())
# Out:
# # ---------------------------------------------------------
# # Copyright (c) Microsoft Corporation. All rights reserved.
# # ---------------------------------------------------------
# import json
# import pickle
# import numpy as np
# import pandas as pd
# import azureml.train.automl
# from sklearn.externals import joblib
# from azureml.core.model import Model
#
# from inference_schema.schema_decorators import input_schema, output_schema
# from inference_schema.parameter_types.numpy_parameter_type import NumpyParameterType
# from inference_schema.parameter_types.pandas_parameter_type import PandasParameterType
#
#
# input_sample = pd.DataFrame(data=[{'RowID': 0, 'GR': 99.0, 'smoothedGR': 104.0, 'FirstRow': 'First', 'smoothedGR1': None, 'smoothedGR-1': 104.0, 'smoothedGR2': None, 'smoothedGR-2': 104.1, 'smoothedGR3': None, 'smoothedGR-3': 104.1, 'smoothedGR4': None, 'smoothedGR-4': 104.2, 'smoothedDifference': 0.0, 'smoothedDifference_SMA': -2.8, 'smoothedDifference_SMA_4': None, 'smoothedDifference_SMA_8': None, 'smoothedDifference_SMA_12': None, 'smoothedDifference_SMA_16': None, 'smoothedDifference_SMA_20': None, 'smoothedDifference_SMA_24': None, 'smoothedDifference_SMA_28': None, 'smoothedDifference_SMA_32': None, 'smoothedDifference_SMA_36': None, 'smoothedDifference_SMA_40': None, 'smoothedDifference_SMA_FORWARD_4': -1.1, 'smoothedDifference_SMA_FORWARD_8': 4.5, 'smoothedDifference_SMA_FORWARD_12': -3.2, 'smoothedDifference_SMA_FORWARD_16': 0.7, 'smoothedDifference_SMA_FORWARD_20': 0.3, 'smoothedDifference_SMA_FORWARD_24': 1.6, 'smoothedDifference_SMA_FORWARD_28': -0.8, 'smoothedDifference_SMA_FORWARD_32': -2.0, 'smoothedDifference_SMA_FORWARD_36': 2.6, 'smoothedDifference_SMA_FORWARD_40': -1.6}])
# output_sample = np.array([0])
#
#
# def init():
#     global model
#     # This name is model.id of model that we want to deploy deserialize the model file back
#     # into a sklearn model
#     model_path = Model.get_model_path(model_name = 'AutoML37a31f86512')
#     model = joblib.load(model_path)
#
#
# @input_schema('data', PandasParameterType(input_sample))
# @output_schema(NumpyParameterType(output_sample))
# def run(data):
#     try:
#         result = model.predict(data)
#         return json.dumps({"result": result.tolist()})
#     except Exception as e:
#         result = str(e)
#         return json.dumps({"error": result})

# %%
testJson
# Out:
# {'data': [{'RowID': 0,
#    'GR': 110.5,
#    'smoothedGR': 108.1,
#    'FirstRow': 'First',
#    'smoothedGR1': None,
#    'smoothedGR-1': 108.1,
#    'smoothedGR2': None,
#    'smoothedGR-2': 108.1,
#    'smoothedGR3': None,
#    'smoothedGR-3': 108.1,
#    'smoothedGR4': None,
#    'smoothedGR-4': 108.1,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': None,
#    'smoothedDifference_SMA_8': None,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 1,
#    'GR': 116.6,
#    'smoothedGR': 108.1,
#    'FirstRow': 'Other',
#    'smoothedGR1': 108.1,
#    'smoothedGR-1': 108.1,
#    'smoothedGR2': None,
#    'smoothedGR-2': 108.1,
#    'smoothedGR3': None,
#    'smoothedGR-3': 108.1,
#    'smoothedGR4': None,
#    'smoothedGR-4': 108.0,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': None,
#    'smoothedDifference_SMA_8': None,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 2,
#    'GR': 108.4,
#    'smoothedGR': 108.1,
#    'FirstRow': 'Other',
#    'smoothedGR1': 108.1,
#    'smoothedGR-1': 108.1,
#    'smoothedGR2': 108.1,
#    'smoothedGR-2': 108.1,
#    'smoothedGR3': None,
#    'smoothedGR-3': 108.0,
#    'smoothedGR4': None,
#    'smoothedGR-4': 108.0,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': None,
#    'smoothedDifference_SMA_8': None,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 3,
#    'GR': 101.4,
#    'smoothedGR': 108.1,
#    'FirstRow': 'Other',
#    'smoothedGR1': 108.1,
#    'smoothedGR-1': 108.1,
#    'smoothedGR2': 108.1,
#    'smoothedGR-2': 108.0,
#    'smoothedGR3': 108.1,
#    'smoothedGR-3': 108.0,
#    'smoothedGR4': None,
#    'smoothedGR-4': 107.9,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': None,
#    'smoothedDifference_SMA_8': None,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 4,
#    'GR': 100.8,
#    'smoothedGR': 108.1,
#    'FirstRow': 'Other',
#    'smoothedGR1': 108.1,
#    'smoothedGR-1': 108.0,
#    'smoothedGR2': 108.1,
#    'smoothedGR-2': 108.0,
#    'smoothedGR3': 108.1,
#    'smoothedGR-3': 107.9,
#    'smoothedGR4': 108.1,
#    'smoothedGR-4': 107.9,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': None,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 5,
#    'GR': 108.1,
#    'smoothedGR': 108.0,
#    'FirstRow': 'Other',
#    'smoothedGR1': 108.1,
#    'smoothedGR-1': 108.0,
#    'smoothedGR2': 108.1,
#    'smoothedGR-2': 107.9,
#    'smoothedGR3': 108.1,
#    'smoothedGR-3': 107.9,
#    'smoothedGR4': 108.1,
#    'smoothedGR-4': 107.8,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': None,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 6,
#    'GR': 112.6,
#    'smoothedGR': 108.0,
#    'FirstRow': 'Other',
#    'smoothedGR1': 108.0,
#    'smoothedGR-1': 107.9,
#    'smoothedGR2': 108.1,
#    'smoothedGR-2': 107.9,
#    'smoothedGR3': 108.1,
#    'smoothedGR-3': 107.8,
#    'smoothedGR4': 108.1,
#    'smoothedGR-4': 107.8,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': None,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 7,
#    'GR': 106.2,
#    'smoothedGR': 107.9,
#    'FirstRow': 'Other',
#    'smoothedGR1': 108.0,
#    'smoothedGR-1': 107.9,
#    'smoothedGR2': 108.0,
#    'smoothedGR-2': 107.8,
#    'smoothedGR3': 108.1,
#    'smoothedGR-3': 107.8,
#    'smoothedGR4': 108.1,
#    'smoothedGR-4': 107.8,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': None,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 8,
#    'GR': 105.7,
#    'smoothedGR': 107.9,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.9,
#    'smoothedGR-1': 107.8,
#    'smoothedGR2': 108.0,
#    'smoothedGR-2': 107.8,
#    'smoothedGR3': 108.0,
#    'smoothedGR-3': 107.8,
#    'smoothedGR4': 108.1,
#    'smoothedGR-4': 107.7,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 9,
#    'GR': 116.9,
#    'smoothedGR': 107.8,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.9,
#    'smoothedGR-1': 107.8,
#    'smoothedGR2': 107.9,
#    'smoothedGR-2': 107.8,
#    'smoothedGR3': 108.0,
#    'smoothedGR-3': 107.7,
#    'smoothedGR4': 108.0,
#    'smoothedGR-4': 107.7,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 10,
#    'GR': 101.4,
#    'smoothedGR': 107.8,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.8,
#    'smoothedGR-1': 107.8,
#    'smoothedGR2': 107.9,
#    'smoothedGR-2': 107.7,
#    'smoothedGR3': 107.9,
#    'smoothedGR-3': 107.7,
#    'smoothedGR4': 108.0,
#    'smoothedGR-4': 107.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 11,
#    'GR': 104.5,
#    'smoothedGR': 107.8,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.8,
#    'smoothedGR-1': 107.7,
#    'smoothedGR2': 107.8,
#    'smoothedGR-2': 107.7,
#    'smoothedGR3': 107.9,
#    'smoothedGR-3': 107.6,
#    'smoothedGR4': 107.9,
#    'smoothedGR-4': 107.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': None,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 12,
#    'GR': 114.3,
#    'smoothedGR': 107.7,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.8,
#    'smoothedGR-1': 107.7,
#    'smoothedGR2': 107.8,
#    'smoothedGR-2': 107.6,
#    'smoothedGR3': 107.8,
#    'smoothedGR-3': 107.6,
#    'smoothedGR4': 107.9,
#    'smoothedGR-4': 107.5,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 13,
#    'GR': 103.6,
#    'smoothedGR': 107.7,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.7,
#    'smoothedGR-1': 107.6,
#    'smoothedGR2': 107.8,
#    'smoothedGR-2': 107.6,
#    'smoothedGR3': 107.8,
#    'smoothedGR-3': 107.5,
#    'smoothedGR4': 107.8,
#    'smoothedGR-4': 107.5,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 14,
#    'GR': 111.2,
#    'smoothedGR': 107.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.7,
#    'smoothedGR-1': 107.6,
#    'smoothedGR2': 107.7,
#    'smoothedGR-2': 107.5,
#    'smoothedGR3': 107.8,
#    'smoothedGR-3': 107.5,
#    'smoothedGR4': 107.8,
#    'smoothedGR-4': 107.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 15,
#    'GR': 109.1,
#    'smoothedGR': 107.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.6,
#    'smoothedGR-1': 107.5,
#    'smoothedGR2': 107.7,
#    'smoothedGR-2': 107.5,
#    'smoothedGR3': 107.7,
#    'smoothedGR-3': 107.6,
#    'smoothedGR4': 107.8,
#    'smoothedGR-4': 107.5,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': None,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 16,
#    'GR': 103.4,
#    'smoothedGR': 107.5,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.6,
#    'smoothedGR-1': 107.5,
#    'smoothedGR2': 107.6,
#    'smoothedGR-2': 107.6,
#    'smoothedGR3': 107.7,
#    'smoothedGR-3': 107.5,
#    'smoothedGR4': 107.7,
#    'smoothedGR-4': 107.5,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 17,
#    'GR': 108.9,
#    'smoothedGR': 107.5,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.5,
#    'smoothedGR-1': 107.6,
#    'smoothedGR2': 107.6,
#    'smoothedGR-2': 107.5,
#    'smoothedGR3': 107.6,
#    'smoothedGR-3': 107.5,
#    'smoothedGR4': 107.7,
#    'smoothedGR-4': 107.5,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 18,
#    'GR': 109.3,
#    'smoothedGR': 107.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.5,
#    'smoothedGR-1': 107.5,
#    'smoothedGR2': 107.5,
#    'smoothedGR-2': 107.5,
#    'smoothedGR3': 107.6,
#    'smoothedGR-3': 107.5,
#    'smoothedGR4': 107.6,
#    'smoothedGR-4': 107.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 19,
#    'GR': 106.4,
#    'smoothedGR': 107.5,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.6,
#    'smoothedGR-1': 107.5,
#    'smoothedGR2': 107.5,
#    'smoothedGR-2': 107.5,
#    'smoothedGR3': 107.5,
#    'smoothedGR-3': 107.6,
#    'smoothedGR4': 107.6,
#    'smoothedGR-4': 107.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': None,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 20,
#    'GR': 103.5,
#    'smoothedGR': 107.5,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.5,
#    'smoothedGR-1': 107.5,
#    'smoothedGR2': 107.6,
#    'smoothedGR-2': 107.6,
#    'smoothedGR3': 107.5,
#    'smoothedGR-3': 107.6,
#    'smoothedGR4': 107.5,
#    'smoothedGR-4': 107.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 21,
#    'GR': 104.5,
#    'smoothedGR': 107.5,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.5,
#    'smoothedGR-1': 107.6,
#    'smoothedGR2': 107.5,
#    'smoothedGR-2': 107.6,
#    'smoothedGR3': 107.6,
#    'smoothedGR-3': 107.6,
#    'smoothedGR4': 107.5,
#    'smoothedGR-4': 107.7,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 22,
#    'GR': 107.9,
#    'smoothedGR': 107.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.5,
#    'smoothedGR-1': 107.6,
#    'smoothedGR2': 107.5,
#    'smoothedGR-2': 107.6,
#    'smoothedGR3': 107.5,
#    'smoothedGR-3': 107.7,
#    'smoothedGR4': 107.6,
#    'smoothedGR-4': 107.7,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 23,
#    'GR': 113.4,
#    'smoothedGR': 107.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.6,
#    'smoothedGR-1': 107.6,
#    'smoothedGR2': 107.5,
#    'smoothedGR-2': 107.7,
#    'smoothedGR3': 107.5,
#    'smoothedGR-3': 107.7,
#    'smoothedGR4': 107.5,
#    'smoothedGR-4': 107.7,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': None,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 24,
#    'GR': 109.4,
#    'smoothedGR': 107.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.6,
#    'smoothedGR-1': 107.7,
#    'smoothedGR2': 107.6,
#    'smoothedGR-2': 107.7,
#    'smoothedGR3': 107.5,
#    'smoothedGR-3': 107.7,
#    'smoothedGR4': 107.5,
#    'smoothedGR-4': 107.8,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 25,
#    'GR': 106.2,
#    'smoothedGR': 107.7,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.6,
#    'smoothedGR-1': 107.7,
#    'smoothedGR2': 107.6,
#    'smoothedGR-2': 107.7,
#    'smoothedGR3': 107.6,
#    'smoothedGR-3': 107.8,
#    'smoothedGR4': 107.5,
#    'smoothedGR-4': 107.7,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 26,
#    'GR': 104.3,
#    'smoothedGR': 107.7,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.7,
#    'smoothedGR-1': 107.7,
#    'smoothedGR2': 107.6,
#    'smoothedGR-2': 107.8,
#    'smoothedGR3': 107.6,
#    'smoothedGR-3': 107.7,
#    'smoothedGR4': 107.6,
#    'smoothedGR-4': 107.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 27,
#    'GR': 106.7,
#    'smoothedGR': 107.7,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.7,
#    'smoothedGR-1': 107.8,
#    'smoothedGR2': 107.7,
#    'smoothedGR-2': 107.7,
#    'smoothedGR3': 107.6,
#    'smoothedGR-3': 107.6,
#    'smoothedGR4': 107.6,
#    'smoothedGR-4': 107.3,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': None,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 28,
#    'GR': 107.9,
#    'smoothedGR': 107.8,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.7,
#    'smoothedGR-1': 107.7,
#    'smoothedGR2': 107.7,
#    'smoothedGR-2': 107.6,
#    'smoothedGR3': 107.7,
#    'smoothedGR-3': 107.3,
#    'smoothedGR4': 107.6,
#    'smoothedGR-4': 107.0,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 29,
#    'GR': 112.3,
#    'smoothedGR': 107.7,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.8,
#    'smoothedGR-1': 107.6,
#    'smoothedGR2': 107.7,
#    'smoothedGR-2': 107.3,
#    'smoothedGR3': 107.7,
#    'smoothedGR-3': 107.0,
#    'smoothedGR4': 107.7,
#    'smoothedGR-4': 106.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 30,
#    'GR': 106.8,
#    'smoothedGR': 107.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.7,
#    'smoothedGR-1': 107.3,
#    'smoothedGR2': 107.8,
#    'smoothedGR-2': 107.0,
#    'smoothedGR3': 107.7,
#    'smoothedGR-3': 106.6,
#    'smoothedGR4': 107.7,
#    'smoothedGR-4': 106.1,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 31,
#    'GR': 110.4,
#    'smoothedGR': 107.3,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.6,
#    'smoothedGR-1': 107.0,
#    'smoothedGR2': 107.7,
#    'smoothedGR-2': 106.6,
#    'smoothedGR3': 107.8,
#    'smoothedGR-3': 106.1,
#    'smoothedGR4': 107.7,
#    'smoothedGR-4': 105.3,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': None,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 32,
#    'GR': 106.9,
#    'smoothedGR': 107.0,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.3,
#    'smoothedGR-1': 106.6,
#    'smoothedGR2': 107.6,
#    'smoothedGR-2': 106.1,
#    'smoothedGR3': 107.7,
#    'smoothedGR-3': 105.3,
#    'smoothedGR4': 107.8,
#    'smoothedGR-4': 104.4,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 33,
#    'GR': 107.2,
#    'smoothedGR': 106.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 107.0,
#    'smoothedGR-1': 106.1,
#    'smoothedGR2': 107.3,
#    'smoothedGR-2': 105.3,
#    'smoothedGR3': 107.6,
#    'smoothedGR-3': 104.4,
#    'smoothedGR4': 107.7,
#    'smoothedGR-4': 103.3,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 34,
#    'GR': 107.0,
#    'smoothedGR': 106.1,
#    'FirstRow': 'Other',
#    'smoothedGR1': 106.6,
#    'smoothedGR-1': 105.3,
#    'smoothedGR2': 107.0,
#    'smoothedGR-2': 104.4,
#    'smoothedGR3': 107.3,
#    'smoothedGR-3': 103.3,
#    'smoothedGR4': 107.6,
#    'smoothedGR-4': 102.0,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 35,
#    'GR': 107.4,
#    'smoothedGR': 105.3,
#    'FirstRow': 'Other',
#    'smoothedGR1': 106.1,
#    'smoothedGR-1': 104.4,
#    'smoothedGR2': 106.6,
#    'smoothedGR-2': 103.3,
#    'smoothedGR3': 107.0,
#    'smoothedGR-3': 102.0,
#    'smoothedGR4': 107.3,
#    'smoothedGR-4': 100.5,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': None,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 36,
#    'GR': 108.1,
#    'smoothedGR': 104.4,
#    'FirstRow': 'Other',
#    'smoothedGR1': 105.3,
#    'smoothedGR-1': 103.3,
#    'smoothedGR2': 106.1,
#    'smoothedGR-2': 102.0,
#    'smoothedGR3': 106.6,
#    'smoothedGR-3': 100.5,
#    'smoothedGR4': 107.0,
#    'smoothedGR-4': 98.8,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 37,
#    'GR': 105.6,
#    'smoothedGR': 103.3,
#    'FirstRow': 'Other',
#    'smoothedGR1': 104.4,
#    'smoothedGR-1': 102.0,
#    'smoothedGR2': 105.3,
#    'smoothedGR-2': 100.5,
#    'smoothedGR3': 106.1,
#    'smoothedGR-3': 98.8,
#    'smoothedGR4': 106.6,
#    'smoothedGR-4': 97.0,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 38,
#    'GR': 108.3,
#    'smoothedGR': 102.0,
#    'FirstRow': 'Other',
#    'smoothedGR1': 103.3,
#    'smoothedGR-1': 100.5,
#    'smoothedGR2': 104.4,
#    'smoothedGR-2': 98.8,
#    'smoothedGR3': 105.3,
#    'smoothedGR-3': 97.0,
#    'smoothedGR4': 106.1,
#    'smoothedGR-4': 95.1,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 39,
#    'GR': 106.8,
#    'smoothedGR': 100.5,
#    'FirstRow': 'Other',
#    'smoothedGR1': 102.0,
#    'smoothedGR-1': 98.8,
#    'smoothedGR2': 103.3,
#    'smoothedGR-2': 97.0,
#    'smoothedGR3': 104.4,
#    'smoothedGR-3': 95.1,
#    'smoothedGR4': 105.3,
#    'smoothedGR-4': 92.9,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': None,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 40,
#    'GR': 105.9,
#    'smoothedGR': 98.8,
#    'FirstRow': 'Other',
#    'smoothedGR1': 100.5,
#    'smoothedGR-1': 97.0,
#    'smoothedGR2': 102.0,
#    'smoothedGR-2': 95.1,
#    'smoothedGR3': 103.3,
#    'smoothedGR-3': 92.9,
#    'smoothedGR4': 104.4,
#    'smoothedGR-4': 90.8,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 41,
#    'GR': 107.7,
# ...
#    'smoothedGR-3': 81.3,
#    'smoothedGR4': 92.1,
#    'smoothedGR-4': 78.0,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 987,
#    'GR': 85.0,
#    'smoothedGR': 86.8,
#    'FirstRow': 'Other',
#    'smoothedGR1': 89.0,
#    'smoothedGR-1': 84.1,
#    'smoothedGR2': 90.8,
#    'smoothedGR-2': 81.3,
#    'smoothedGR3': 92.0,
#    'smoothedGR-3': 78.0,
#    'smoothedGR4': 92.4,
#    'smoothedGR-4': 74.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 988,
#    'GR': 80.3,
#    'smoothedGR': 84.1,
#    'FirstRow': 'Other',
#    'smoothedGR1': 86.8,
#    'smoothedGR-1': 81.3,
#    'smoothedGR2': 89.0,
#    'smoothedGR-2': 78.0,
#    'smoothedGR3': 90.8,
#    'smoothedGR-3': 74.6,
#    'smoothedGR4': 92.0,
#    'smoothedGR-4': 71.2,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 989,
#    'GR': 78.7,
#    'smoothedGR': 81.3,
#    'FirstRow': 'Other',
#    'smoothedGR1': 84.1,
#    'smoothedGR-1': 78.0,
#    'smoothedGR2': 86.8,
#    'smoothedGR-2': 74.6,
#    'smoothedGR3': 89.0,
#    'smoothedGR-3': 71.2,
#    'smoothedGR4': 90.8,
#    'smoothedGR-4': 67.8,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 990,
#    'GR': 76.8,
#    'smoothedGR': 78.0,
#    'FirstRow': 'Other',
#    'smoothedGR1': 81.3,
#    'smoothedGR-1': 74.6,
#    'smoothedGR2': 84.1,
#    'smoothedGR-2': 71.2,
#    'smoothedGR3': 86.8,
#    'smoothedGR-3': 67.8,
#    'smoothedGR4': 89.0,
#    'smoothedGR-4': 64.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 991,
#    'GR': 74.5,
#    'smoothedGR': 74.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 78.0,
#    'smoothedGR-1': 71.2,
#    'smoothedGR2': 81.3,
#    'smoothedGR-2': 67.8,
#    'smoothedGR3': 84.1,
#    'smoothedGR-3': 64.6,
#    'smoothedGR4': 86.8,
#    'smoothedGR-4': 61.5,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 992,
#    'GR': 71.2,
#    'smoothedGR': 71.2,
#    'FirstRow': 'Other',
#    'smoothedGR1': 74.6,
#    'smoothedGR-1': 67.8,
#    'smoothedGR2': 78.0,
#    'smoothedGR-2': 64.6,
#    'smoothedGR3': 81.3,
#    'smoothedGR-3': 61.5,
#    'smoothedGR4': 84.1,
#    'smoothedGR-4': 58.7,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 993,
#    'GR': 59.5,
#    'smoothedGR': 67.8,
#    'FirstRow': 'Other',
#    'smoothedGR1': 71.2,
#    'smoothedGR-1': 64.6,
#    'smoothedGR2': 74.6,
#    'smoothedGR-2': 61.5,
#    'smoothedGR3': 78.0,
#    'smoothedGR-3': 58.7,
#    'smoothedGR4': 81.3,
#    'smoothedGR-4': 56.1,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 994,
#    'GR': 66.8,
#    'smoothedGR': 64.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 67.8,
#    'smoothedGR-1': 61.5,
#    'smoothedGR2': 71.2,
#    'smoothedGR-2': 58.7,
#    'smoothedGR3': 74.6,
#    'smoothedGR-3': 56.1,
#    'smoothedGR4': 78.0,
#    'smoothedGR-4': 53.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 995,
#    'GR': 65.2,
#    'smoothedGR': 61.5,
#    'FirstRow': 'Other',
#    'smoothedGR1': 64.6,
#    'smoothedGR-1': 58.7,
#    'smoothedGR2': 67.8,
#    'smoothedGR-2': 56.1,
#    'smoothedGR3': 71.2,
#    'smoothedGR-3': 53.6,
#    'smoothedGR4': 74.6,
#    'smoothedGR-4': 51.5,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 996,
#    'GR': 52.2,
#    'smoothedGR': 58.7,
#    'FirstRow': 'Other',
#    'smoothedGR1': 61.5,
#    'smoothedGR-1': 56.1,
#    'smoothedGR2': 64.6,
#    'smoothedGR-2': 53.6,
#    'smoothedGR3': 67.8,
#    'smoothedGR-3': 51.5,
#    'smoothedGR4': 71.2,
#    'smoothedGR-4': 49.6,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 997,
#    'GR': 59.0,
#    'smoothedGR': 56.1,
#    'FirstRow': 'Other',
#    'smoothedGR1': 58.7,
#    'smoothedGR-1': 53.6,
#    'smoothedGR2': 61.5,
#    'smoothedGR-2': 51.5,
#    'smoothedGR3': 64.6,
#    'smoothedGR-3': 49.6,
#    'smoothedGR4': 67.8,
#    'smoothedGR-4': 48.1,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 998,
#    'GR': 44.3,
#    'smoothedGR': 53.6,
#    'FirstRow': 'Other',
#    'smoothedGR1': 56.1,
#    'smoothedGR-1': 51.5,
#    'smoothedGR2': 58.7,
#    'smoothedGR-2': 49.6,
#    'smoothedGR3': 61.5,
#    'smoothedGR-3': 48.1,
#    'smoothedGR4': 64.6,
#    'smoothedGR-4': 46.9,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   {'RowID': 999,
#    'GR': 43.8,
#    'smoothedGR': 51.5,
#    'FirstRow': 'Other',
#    'smoothedGR1': 53.6,
#    'smoothedGR-1': 49.6,
#    'smoothedGR2': 56.1,
#    'smoothedGR-2': 48.1,
#    'smoothedGR3': 58.7,
#    'smoothedGR-3': 46.9,
#    'smoothedGR4': 61.5,
#    'smoothedGR-4': 45.9,
#    'smoothedDifference': 0.0,
#    'smoothedDifference_SMA': 0.0,
#    'smoothedDifference_SMA_4': 0.0,
#    'smoothedDifference_SMA_8': 0.0,
#    'smoothedDifference_SMA_12': 0.0,
#    'smoothedDifference_SMA_16': 0.0,
#    'smoothedDifference_SMA_20': 0.0,
#    'smoothedDifference_SMA_24': 0.0,
#    'smoothedDifference_SMA_28': 0.0,
#    'smoothedDifference_SMA_32': 0.0,
#    'smoothedDifference_SMA_36': 0.0,
#    'smoothedDifference_SMA_40': 0.0,
#    'smoothedDifference_SMA_FORWARD_4': 0.0,
#    'smoothedDifference_SMA_FORWARD_8': 0.0,
#    'smoothedDifference_SMA_FORWARD_12': 0.0,
#    'smoothedDifference_SMA_FORWARD_16': 0.0,
#    'smoothedDifference_SMA_FORWARD_20': 0.0,
#    'smoothedDifference_SMA_FORWARD_24': 0.0,
#    'smoothedDifference_SMA_FORWARD_28': 0.0,
#    'smoothedDifference_SMA_FORWARD_32': 0.0,
#    'smoothedDifference_SMA_FORWARD_36': 0.0,
#    'smoothedDifference_SMA_FORWARD_40': 0.0},
#   ...]}

# %% [markdown]
# ## Test ACI

# %%
# Plug in the URL for your ACI web service.  You can find it easily on ML Studio by clicking endpoints.
scoring_url_aci = 'http://4523f38e-6c26-4f79-aaa1-076c0b5b2913.eastus.azurecontainer.io/score'

# Set the content type to 'application/json'
headers = {'Content-Type': 'application/json'}

# Make the request and display the response
resp = requests.post(scoring_url_aci, input_data, headers=headers)
print(resp.text)
# Out:
# "{\"result\": [\"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 2\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Layer 4\", \"Layer 4\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 2\", \"Layer 1\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Default Layer\", \"Default Layer\", \"Layer 1\", \"Layer 1\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 4\", \"Layer 4\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Layer 4\", \"Default Layer\", \"Default Layer\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 4\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\",  ...

# %% [markdown]
# ## Test AKS

# %%
# Plug in the URL for your AKS web service.  You can find it easily on ML Studio by clicking endpoints.
scoring_uri_aks = 'http://40.117.194.42:80/api/v1/service/automl-ancient-rivers-aks/score'
# Since your AKS service requires authentication, set the key or token
key = '5LYMIt2ZdZiafN2TjZcUQSlhDNXegGYB'

# Set the content type to 'application/json'
headers = {'Content-Type': 'application/json'}
# Set the authorization header for AKS
headers['Authorization'] = f'Bearer {key}'

# Make the request to your deployed model and display the response
resp = requests.post(scoring_uri_aks, input_data, headers=headers)
print(resp.text)
# Out:
# "{\"result\": [\"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 2\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Layer 4\", \"Layer 4\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 2\", \"Layer 1\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Default Layer\", \"Default Layer\", \"Layer 1\", \"Layer 1\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 4\", \"Layer 4\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Default Layer\", \"Layer 4\", \"Default Layer\", \"Default Layer\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 4\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 1\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 4\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\", \"Layer 2\",  ...
