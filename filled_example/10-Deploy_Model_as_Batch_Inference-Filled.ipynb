# %% [markdown]
# # Set Up a Scoring Pipeline
# Pipelines are reusable objects you can use to transform, move and score data.  Scoring pipelines are used for batch execution jobs.<br>
# You should use batch execution scoring jobs when you do not immediately need to receive a prediction from the process.  Some time lag is okay.<br>
# Scoring pipelines are inherently slower than AKS because your compute cluster takes time to spin up.  However, they are much cheaper as a result.<br>
# Typical scenarios for scoring pipelines are when you run a machine model on a daily, weekly or monthly basis and use the output in other reports.
#
# To learn more about scoring pipelines, click here:  https://docs.microsoft.com/en-us/azure/machine-learning/tutorial-pipeline-batch-scoring-classification

# %%
# Load Azure Libaries
from azureml.core import Datastore
from azureml.core.dataset import Dataset
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.experiment import Experiment
from azureml.core.environment import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.automl.core.featurization import FeaturizationConfig
from azureml.core.authentication import InteractiveLoginAuthentication
from azureml.explain.model._internal.explanation_client import ExplanationClient

#Load Libraries for Deployment
from azureml.core.model import Model
from azureml.core.webservice import Webservice
from azureml.core.model import InferenceConfig
from azureml.core.webservice import AciWebservice
from azureml.core.webservice import AksWebservice
from azureml.pipeline.steps import PythonScriptStep
from azureml.data.data_reference import DataReference
from azureml.core.compute import AksCompute, ComputeTarget
from azureml.pipeline.core import Pipeline, PipelineData, PublishedPipeline, PipelineEndpoint
from azureml.core.runconfig import RunConfiguration, CondaDependencies, DEFAULT_CPU_IMAGE
from azureml.widgets import RunDetails

##load libraries for math and data manipulation
import os
import math
import json
import logging
import requests
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Retrieve your workspace by name by filling in the lower case values between double quotes
ws = Workspace.get(name="ancient-rivers-ml-workspace",
        subscription_id="47a7ec0c-37ad-428b-9114-b87ea1057632",
        resource_group="xeek-ancient-rivers")

# %%
# Retrieve your Datastore by name by filling in the lower case values between double quotes
datastore_name = "ancientrivers"
datastore = Datastore.get(ws, datastore_name)

# %%
# Retrieve your Datasets by name by filling in the lower case values between double quotes
dataset_name_test  = "ancient-rivers-test-transformed"
dataset_name_train = "ancient-rivers-train-transformed"

# Load Data in as Tabular Datasets
testing_data  = Dataset.get_by_name(ws, dataset_name_test, version='latest')
training_data = Dataset.get_by_name(ws, dataset_name_train, version='latest')

# %%
# Convert your tabular dataset to pandas data frames
testTransformedDF = testing_data.to_pandas_dataframe()
trainTransformedDF = training_data.to_pandas_dataframe()

# %%
# Retrieve your Compute Targets for Running AutoML
cpu_compute_target = ComputeTarget(ws, 'cpu-cluster-h')
# Retrieve a GPU cluster for Deep Learning Runs
gpu_compute_target = ComputeTarget(ws, 'gpu-cluster')

# %%
# Retrieve your AutoML Model
model = Model(ws, 'AutoML37a31f86512')
# Assign a variable to your model name
model_name = model.name

# %%
# Retrieve your AutoML generated environment
environment = Environment.get(ws, 'automl-environment')

# %%
# Retrieve your AutoML generated entry script
entry_script = 'inference/score.py'

# %% [markdown]
# ### First, you must create your scoring script.
# A scoring script is simply a script that pulls in your model, pulls in data, scores the data with the model, and saves it to an output.<br>If you used AutoML, you can use your score.py as a starting point, but you will need to modify it to read and write data to a specified location.

# %%
# Look at your AutoML Scoring Script
with open(os.path.join(entry_script)) as inference_file:
    print(inference_file.read())
# Out:
# # ---------------------------------------------------------
# # Copyright (c) Microsoft Corporation. All rights reserved.
# # ---------------------------------------------------------
# import json
# import pickle
# import numpy as np
# import pandas as pd
# import azureml.train.automl
# from sklearn.externals import joblib
# from azureml.core.model import Model
#
# from inference_schema.schema_decorators import input_schema, output_schema
# from inference_schema.parameter_types.numpy_parameter_type import NumpyParameterType
# from inference_schema.parameter_types.pandas_parameter_type import PandasParameterType
#
#
# input_sample = pd.DataFrame(data=[{'RowID': 0, 'GR': 99.0, 'smoothedGR': 104.0, 'FirstRow': 'First', 'smoothedGR1': None, 'smoothedGR-1': 104.0, 'smoothedGR2': None, 'smoothedGR-2': 104.1, 'smoothedGR3': None, 'smoothedGR-3': 104.1, 'smoothedGR4': None, 'smoothedGR-4': 104.2, 'smoothedDifference': 0.0, 'smoothedDifference_SMA': -2.8, 'smoothedDifference_SMA_4': None, 'smoothedDifference_SMA_8': None, 'smoothedDifference_SMA_12': None, 'smoothedDifference_SMA_16': None, 'smoothedDifference_SMA_20': None, 'smoothedDifference_SMA_24': None, 'smoothedDifference_SMA_28': None, 'smoothedDifference_SMA_32': None, 'smoothedDifference_SMA_36': None, 'smoothedDifference_SMA_40': None, 'smoothedDifference_SMA_FORWARD_4': -1.1, 'smoothedDifference_SMA_FORWARD_8': 4.5, 'smoothedDifference_SMA_FORWARD_12': -3.2, 'smoothedDifference_SMA_FORWARD_16': 0.7, 'smoothedDifference_SMA_FORWARD_20': 0.3, 'smoothedDifference_SMA_FORWARD_24': 1.6, 'smoothedDifference_SMA_FORWARD_28': -0.8, 'smoothedDifference_SMA_FORWARD_32': -2.0, 'smoothedDifference_SMA_FORWARD_36': 2.6, 'smoothedDifference_SMA_FORWARD_40': -1.6}])
# output_sample = np.array([0])
#
#
# def init():
#     global model
#     # This name is model.id of model that we want to deploy deserialize the model file back
#     # into a sklearn model
#     model_path = Model.get_model_path(model_name = 'AutoML37a31f86512')
#     model = joblib.load(model_path)
#
#
# @input_schema('data', PandasParameterType(input_sample))
# @output_schema(NumpyParameterType(output_sample))
# def run(data):
#     try:
#         result = model.predict(data)
#         return json.dumps({"result": result.tolist()})
#     except Exception as e:
#         result = str(e)
#         return json.dumps({"error": result})

# %% [markdown]
# ### Write your Scoring Script
# The code below is based on AutoML.  Follow these steps:
#
# 1.  Import all of the libraries used to run your score.py file
# 2.  Pass in Arguments.  These are values that will be passed in via your pipeline script.  Model, Input and Output location are common arguments.
# 3.  Retrieve and load your model by name and set it to a global variable.
# 4.  Write your main function.  This code will score the model and write it to a location on your datastore.  However, this code can do whatever you wish.  You can transform your data here, write and output graphs and score a number of metrics.
# 5.  Run your main function.

# %%
# %%writefile inference/ancient-rivers-scoring-script.py
# Pull in Libaries
import json
import pickle
import argparse
import os
from fbprophet import Prophet
import numpy as np
import pandas as pd
import azureml.train.automl
import joblib
from azureml.core.model import Model
from azureml.core import Workspace, Datastore, Dataset, Run

# Pass in Arguments
parser = argparse.ArgumentParser()
parser.add_argument('--model-name', dest="model_name", required=True)
parser.add_argument('--scoring-directory', dest="scoring_directory", required=True)
parser.add_argument('--input-data', dest="input_data", required=True)
args = parser.parse_args() 

global model
# Retrieve Model
model_path = Model.get_model_path(model_name = args.model_name)
model = joblib.load(model_path)

def main():
    #create output directories if they do not exist
    os.makedirs(args.scoring_directory, exist_ok=True)

    # Pull in an input dataset
    DataPath = args.input_data

    # Convert to Pandas Dataframe
    DataDF = pd.read_csv(DataPath)

    # Score Data
    scoredDataResults = pd.Series(model.predict(DataDF))

    # Join Results to original data
    scoredData = DataDF
    scoredData['Label'] = scoredDataResults

    #Save Results
    scoredFileName = "prediction"
    scoredPath = os.path.join(args.scoring_directory, scoredFileName)
    scoredData.to_csv(scoredPath, index = False)
    
if __name__ == '__main__':
    main()
# Out:
# Overwriting inference/ancient-rivers-scoring-script.py

# %% [markdown]
# ### Next, write an environment that supports the scoring script.
# Examine the packages that you used in the scoring script and do a pip freeze to list their versions.<br>
# Also examine the environment file that was initially used to create the model to obtain dependencies.
#
# Learn more about environments here: https://docs.microsoft.com/en-us/azure/machine-learning/how-to-use-environments

# %%
# Examine your environment file
environment
# Out:
# {
#     "name": "automl-environment",
#     "version": "1",
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "python": {
#         "userManagedDependencies": false,
#         "interpreterPath": "python",
#         "condaDependenciesFile": null,
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6.2",
#                 {
#                     "pip": [
#                         "azureml-train-automl-runtime==1.0.85.5",
#                         "inference-schema",
#                         "azureml-explain-model==1.0.85",
#                         "azureml-defaults==1.0.85.1"
#                     ]
#                 },
#                 "numpy>=1.16.0,<=1.16.2",
#                 "pandas>=0.21.0,<=0.23.4",
#                 "scikit-learn>=0.19.0,<=0.20.3",
#                 "py-xgboost<=0.80",
#                 "fbprophet==0.5",
#                 "psutil>=5.2.2,<6.0.0"
#             ],
#             "name": "azureml_c28e5849b99a3505dc34dfaf678707a8"
#         }
#     },
#     "docker": {
#         "enabled": false,
#         "baseImage": "mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04",
#         "baseDockerfile": null,
#         "sharedVolumes": true,
#         "shmSize": null,
#         "arguments": [],
#         "baseImageRegistry": {
#             "address": null,
#             "username": null,
#             "password": null
#         }
#     },
#     "spark": {
#         "repositories": [],
#         "packages": [],
#         "precachePackages": true
#     },
#     "databricks": {
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": [],
#         "jarLibraries": [],
#         "eggLibraries": []
#     },
#     "inferencingStackVersion": null
# }

# %%
conda list
# Out:
# # packages in environment at /anaconda/envs/azureml_py36:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2019.03                  py36_0
# _libgcc_mutex             0.1                        main
# absl-py                   0.9.0                     <pip>
# adal                      1.2.2                     <pip>
# alabaster                 0.7.12                   py36_0
# alembic                   1.3.2                     <pip>
# anaconda                  custom                   py36_1
# anaconda-client           1.7.2                    py36_0
# anaconda-project          0.8.3                      py_0
# ansiwrap                  0.8.4                     <pip>
# applicationinsights       0.11.9                    <pip>
# asn1crypto                1.0.1                    py36_0
# astor                     0.8.1                     <pip>
# astroid                   2.3.1                    py36_0
# astropy                   3.2.1            py36h7b6447c_0
# atomicwrites              1.3.0                    py36_1
# attrs                     19.2.0                     py_0
# azure-common              1.1.24                    <pip>
# azure-graphrbac           0.61.1                    <pip>
# azure-mgmt-authorization  0.60.0                    <pip>
# azure-mgmt-containerregistry 2.8.0                     <pip>
# azure-mgmt-keyvault       2.0.0                     <pip>
# azure-mgmt-resource       7.0.0                     <pip>
# azure-mgmt-storage        7.0.0                     <pip>
# azure-storage-blob        2.1.0                     <pip>
# azure-storage-common      2.1.0                     <pip>
# azureml-automl-core       1.0.85.5                  <pip>
# azureml-automl-runtime    1.0.85.4                  <pip>
# azureml-contrib-datadrift 1.0.83                    <pip>
# azureml-contrib-interpret 1.0.83                    <pip>
# azureml-contrib-notebook  1.0.85                    <pip>
# azureml-contrib-pipeline-steps 1.0.85                    <pip>
# azureml-contrib-reinforcementlearning 1.0.83                    <pip>
# azureml-contrib-server    1.0.85                    <pip>
# azureml-contrib-services  1.0.85                    <pip>
# azureml-core              1.0.85.5                  <pip>
# azureml-datadrift         1.0.83                    <pip>
# azureml-dataprep          1.1.38                    <pip>
# azureml-dataprep-native   13.2.0                    <pip>
# azureml-defaults          1.0.85.1                  <pip>
# azureml-explain-model     1.0.85                    <pip>
# azureml-interpret         1.0.85                    <pip>
# azureml-mlflow            1.0.83                    <pip>
# azureml-model-management-sdk 1.0.1b6.post1             <pip>
# azureml-opendatasets      1.0.83                    <pip>
# azureml-pipeline          1.0.85                    <pip>
# azureml-pipeline-core     1.0.85.1                  <pip>
# azureml-pipeline-steps    1.0.85                    <pip>
# azureml-samples           0+unknown                 <pip>
# azureml-sdk               1.0.85                    <pip>
# azureml-telemetry         1.0.85.1                  <pip>
# azureml-tensorboard       1.0.83                    <pip>
# azureml-train             1.0.85                    <pip>
# azureml-train-automl      1.0.85                    <pip>
# azureml-train-automl-client 1.0.85.4                  <pip>
# azureml-train-automl-runtime 1.0.85.5                  <pip>
# azureml-train-core        1.0.85                    <pip>
# azureml-train-restclients-hyperdrive 1.0.85                    <pip>
# azureml-widgets           1.0.85.1                  <pip>
# babel                     2.7.0                      py_0
# backcall                  0.1.0                    py36_0
# backports                 1.0                        py_2
# backports.os              0.1.1                    py36_0
# backports.shutil_get_terminal_size 1.0.0                    py36_2
# backports.tempfile        1.0                       <pip>
# backports.weakref         1.0.post1                 <pip>
# beautifulsoup4            4.8.0                    py36_0
# bitarray                  1.0.1            py36h7b6447c_0
# bkcharts                  0.2                      py36_0
# blas                      1.0                         mkl
# bleach                    3.1.0                    py36_0
# blosc                     1.16.3               hd408876_0
# bokeh                     1.3.4                    py36_0
# boto                      2.49.0                   py36_0
# boto3                     1.10.48                   <pip>
# botocore                  1.13.48                   <pip>
# bottleneck                1.2.1            py36h035aef0_1
# bzip2                     1.0.8                h7b6447c_0
# ca-certificates           2019.11.28           hecc5488_0    conda-forge
# cachetools                4.0.0                     <pip>
# cairo                     1.16.0            hfb77d84_1002    conda-forge
# certifi                   2019.11.28               py36_0    conda-forge
# cffi                      1.12.3           py36h2e261b9_0
# chardet                   3.0.4                 py36_1003
# click                     7.0                      py36_0
# cloudpickle               1.2.2                      py_0
# clyent                    1.2.2                    py36_1
# cmdstanpy                 0.4.0                     <pip>
# colorama                  0.4.1                    py36_0
# configparser              3.7.4                     <pip>
# contextlib2               0.6.0                      py_0
# convertdate               2.2.0                     <pip>
# cryptography              2.7              py36h1ba5d50_0
# cssselect                 1.1.0                     <pip>
# cudatoolkit               10.1.243             h6bb024c_0
# curl                      7.65.3               hbc83047_0
# cycler                    0.10.0                   py36_0
# cython                    0.29.14          py36he6710b0_0
# cytoolz                   0.10.0           py36h7b6447c_0
# dask                      2.5.2                      py_0
# dask-core                 2.5.2                      py_0
# databricks-cli            0.9.1                     <pip>
# dbus                      1.13.6               h746ee38_0
# decorator                 4.4.0                    py36_1
# defusedxml                0.6.0                      py_0
# dill                      0.3.1.1                   <pip>
# distributed               2.5.2                      py_0
# distro                    1.4.0                     <pip>
# docker                    4.1.0                     <pip>
# docutils                  0.15.2                   py36_0
# dotnetcore2               2.1.11                    <pip>
# entrypoints               0.3                      py36_0
# enum34                    1.1.6                     <pip>
# ephem                     3.7.7.1                   <pip>
# et_xmlfile                1.0.1                    py36_0
# expat                     2.2.6                he6710b0_0
# fastcache                 1.1.0            py36h7b6447c_0
# fbprophet                 0.6                       <pip>
# filelock                  3.0.12                     py_0
# fire                      0.2.1                     <pip>
# flake8                    3.7.9                     <pip>
# flask                     1.1.1                      py_0
# Flask                     1.0.3                     <pip>
# fontconfig                2.13.1            h86ecdb6_1001    conda-forge
# freetype                  2.9.1                h8a8886c_1
# fribidi                   1.0.5                h7b6447c_0
# fsspec                    0.5.2                      py_0
# fusepy                    3.0.1                     <pip>
# future                    0.18.2                    <pip>
# gast                      0.2.2                     <pip>
# gensim                    3.8.1                     <pip>
# get_terminal_size         1.0.0                haa9412d_0
# gettext                   0.19.8.1          hc5be6a0_1002    conda-forge
# gevent                    1.4.0            py36h7b6447c_0
# gitdb2                    2.0.6                     <pip>
# GitPython                 3.0.5                     <pip>
# glib                      2.58.3          py36h6f030ca_1002    conda-forge
# glob2                     0.7                        py_0
# gmp                       6.1.2                h6c8ec71_1
# gmpy2                     2.0.8            py36h10f8cd9_2
# google-auth               1.10.0                    <pip>
# google-auth-oauthlib      0.4.1                     <pip>
# google-pasta              0.1.8                     <pip>
# gorilla                   0.3.0                     <pip>
# graphite2                 1.3.13               h23475e2_0
# greenlet                  0.4.15           py36h7b6447c_0
# grpcio                    1.26.0                    <pip>
# gst-plugins-base          1.14.5               h0935bb2_0    conda-forge
# gstreamer                 1.14.5               h36ae1b5_0    conda-forge
# gunicorn                  19.9.0                    <pip>
# h5py                      2.9.0            py36h7918eee_0
# harfbuzz                  2.4.0                h9f30f68_3    conda-forge
# hdf5                      1.10.4               hb1b8bf9_0
# heapdict                  1.0.1                      py_0
# holidays                  0.10.1                    <pip>
# horovod                   0.16.4                    <pip>
# html5lib                  1.0.1                    py36_0
# icu                       64.2                 he1b5a44_1    conda-forge
# idna                      2.8                      py36_0
# imageio                   2.6.0                    py36_0
# imagesize                 1.1.0                    py36_0
# importlib_metadata        0.23                     py36_0
# intel-openmp              2019.4                      243
# interpret-community       0.4.1                     <pip>
# interpret-core            0.1.19                    <pip>
# ipykernel                 5.1.3            py36h39e3cac_0
# ipython                   7.8.0            py36h39e3cac_0
# ipython_genutils          0.2.0                    py36_0
# ipywidgets                7.5.1                      py_0
# isodate                   0.6.0                     <pip>
# isort                     4.3.21                   py36_0
# itsdangerous              1.1.0                    py36_0
# jbig                      2.1                  hdba287a_0
# jdcal                     1.4.1                      py_0
# jedi                      0.15.1                   py36_0
# jeepney                   0.4.1                      py_0
# jinja2                    2.10.3                     py_0
# jmespath                  0.9.4                     <pip>
# joblib                    0.14.1                     py_0
# jpeg                      9c                h14c3975_1001    conda-forge
# json-logging-py           0.2                       <pip>
# json5                     0.8.5                      py_0
# JsonForm                  0.0.2                     <pip>
# jsonpickle                1.2                       <pip>
# jsonschema                3.0.2                    py36_0
# JsonSir                   0.0.2                     <pip>
# jupyter                   1.0.0                    py36_7
# jupyter_client            5.3.3                    py36_1
# jupyter_console           6.0.0                    py36_0
# jupyter_core              4.5.0                      py_0
# jupyterlab                1.1.4                      py_0    conda-forge
# jupyterlab-git            0.9.0                     <pip>
# jupyterlab_server         1.0.6                      py_0
# jupytext                  1.3.2                     <pip>
# Keras                     2.3.1                     <pip>
# Keras-Applications        1.0.8                     <pip>
# Keras-Preprocessing       1.1.0                     <pip>
# keras2onnx                1.6.0                     <pip>
# keyring                   18.0.0                   py36_0
# kiwisolver                1.1.0            py36he6710b0_0
# krb5                      1.16.1               h173b8e3_7
# lazy-object-proxy         1.4.2            py36h7b6447c_0
# liac-arff                 2.4.0                     <pip>
# libarchive                3.3.3                h5d8350f_5
# libcurl                   7.65.3               h20c2e04_0
# libedit                   3.1.20181209         hc058e9b_0
# libffi                    3.2.1                hd88cf55_4
# libgcc-ng                 9.1.0                hdf63c60_0
# libgfortran-ng            7.3.0                hdf63c60_0
# libiconv                  1.15              h516909a_1005    conda-forge
# liblief                   0.9.0                h7725739_2
# libpng                    1.6.37               hbc83047_0
# libsodium                 1.0.16               h1bed415_0
# libssh2                   1.8.2                h1ba5d50_0
# libstdcxx-ng              9.1.0                hdf63c60_0
# libtiff                   4.0.10               h2733197_2
# libtool                   2.4.6                h7b6447c_5
# libuuid                   2.32.1            h14c3975_1000    conda-forge
# libuv                     1.33.1               h516909a_0    conda-forge
# libxcb                    1.13                 h1bed415_1
# libxml2                   2.9.9                hea5a465_1
# libxslt                   1.1.33               h31b3aaa_0    conda-forge
# lightgbm                  2.3.0                     <pip>
# llvmlite                  0.29.0           py36hd408876_0
# locket                    0.2.0                    py36_1
# LunarCalendar             0.0.9                     <pip>
# lxml                      4.4.1            py36hefd8a0e_0
# lz4-c                     1.8.1.2              h14c3975_0
# lzo                       2.10                 h49e0be7_2
# Mako                      1.1.0                     <pip>
# Markdown                  3.1.1                     <pip>
# markupsafe                1.1.1            py36h7b6447c_0
# matplotlib                3.1.2                    py36_1    conda-forge
# matplotlib-base           3.1.2            py36h250f245_1    conda-forge
# mccabe                    0.6.1                    py36_1
# mistune                   0.8.4            py36h7b6447c_0
# mkl                       2019.4                      243
# mkl-service               2.3.0            py36he904b0f_0
# mkl_fft                   1.0.14           py36ha843d7b_0
# mkl_random                1.1.0            py36hd6b4f25_0
# mlflow                    1.5.0                     <pip>
# mock                      3.0.5                    py36_0
# more-itertools            7.2.0                    py36_0
# mpc                       1.1.0                h10f8cd9_1
# mpfr                      4.0.1                hdf1c602_3
# mpmath                    1.1.0                    py36_0
# msgpack-python            0.6.1            py36hfd86e86_1
# msrest                    0.6.10                    <pip>
# msrestazure               0.6.2                     <pip>
# multimethods              1.0.0                     <pip>
# multipledispatch          0.6.0                    py36_0
# nb_conda_kernels          2.2.2                    py36_0    conda-forge
# nbconvert                 5.6.1                     <pip>
# nbconvert                 5.6.0                    py36_1
# nbdime                    1.1.0                     <pip>
# nbformat                  4.4.0                    py36_0
# ncurses                   6.1                  he6710b0_1
# ndg-httpsclient           0.5.1                     <pip>
# networkx                  2.3                        py_0
# nimbusml                  1.6.1                     <pip>
# ninja                     1.9.0            py36hfd86e86_0
# nltk                      3.4.5                    py36_0
# nodejs                    13.0.0               h10a4023_1    conda-forge
# nose                      1.3.7                    py36_2
# notebook                  6.0.1                    py36_0
# notebook                  6.0.0                     <pip>
# numba                     0.45.1           py36h962f231_0
# numexpr                   2.7.0            py36h9e4a6bb_0
# numpy                     1.17.4           py36hc1035e2_0
# numpy                     1.16.2                    <pip>
# numpy-base                1.17.4           py36hde5b4d6_0
# numpydoc                  0.9.1                      py_0
# oauthlib                  3.1.0                     <pip>
# olefile                   0.46                     py36_0
# onnx                      1.6.0                     <pip>
# onnxconverter-common      1.6.0                     <pip>
# onnxmltools               1.4.1                     <pip>
# openpyxl                  3.0.0                      py_0
# openssl                   1.1.1d               h516909a_0    conda-forge
# opt-einsum                3.1.0                     <pip>
# packaging                 19.2                       py_0
# pandas                    0.25.1           py36he6710b0_0
# pandas                    0.23.4                    <pip>
# pandas-ml                 0.6.1                     <pip>
# pandoc                    2.2.3.2                       0
# pandocfilters             1.4.2                    py36_1
# pango                     1.42.4               ha030887_1    conda-forge
# papermill                 1.2.1                     <pip>
# parsel                    1.5.2                     <pip>
# parso                     0.5.1                      py_0
# partd                     1.0.0                      py_0
# patchelf                  0.9                  he6710b0_3
# path.py                   12.0.1                     py_0
# pathlib2                  2.3.5                    py36_0
# pathspec                  0.7.0                     <pip>
# patsy                     0.5.1                    py36_0
# pcre                      8.43                 he6710b0_0
# pep8                      1.7.1                    py36_0
# pexpect                   4.7.0                    py36_0
# pickleshare               0.7.5                    py36_0
# pillow                    6.2.0            py36h34e0f95_0
# pip                       19.2.3                   py36_0
# pixman                    0.38.0               h7b6447c_0
# pkginfo                   1.5.0.1                  py36_0
# pluggy                    0.13.0                   py36_0
# ply                       3.11                     py36_0
# pmdarima                  1.1.1                     <pip>
# prometheus-flask-exporter 0.12.1                    <pip>
# prometheus_client         0.7.1                      py_0
# prompt_toolkit            2.0.10                     py_0
# protobuf                  3.11.2                    <pip>
# psutil                    5.6.3            py36h7b6447c_0
# ptyprocess                0.6.0                    py36_0
# py                        1.8.0                    py36_0
# py-cpuinfo                5.0.0                     <pip>
# py-lief                   0.9.0            py36h7725739_2
# py4j                      0.10.7                    <pip>
# pyarrow                   0.15.1                    <pip>
# pyasn1                    0.4.8                     <pip>
# pyasn1-modules            0.2.7                     <pip>
# pycodestyle               2.5.0                    py36_0
# pycosat                   0.6.3            py36h14c3975_0
# pycparser                 2.19                     py36_0
# pycrypto                  2.6.1            py36h14c3975_9
# pycurl                    7.43.0.3         py36h1ba5d50_0
# pyflakes                  2.1.1                    py36_0
# pygments                  2.4.2                      py_0
# PyJWT                     1.7.1                     <pip>
# pylint                    2.4.2                    py36_0
# PyMeeus                   0.3.7                     <pip>
# pyodbc                    4.0.27           py36he6710b0_0
# pyopenssl                 19.0.0                   py36_0
# pyparsing                 2.4.2                      py_0
# pyqt                      5.9.2            py36h05f1152_2
# pyrsistent                0.15.4           py36h7b6447c_0
# pysocks                   1.7.1                    py36_0
# pyspark                   2.4.4                     <pip>
# pystan                    2.19.1.1                  <pip>
# pytables                  3.5.2            py36h71ec239_1
# pytest                    5.0.1                    py36_0
# pytest-arraydiff          0.3              py36h39e3cac_0
# pytest-astropy            0.5.0                    py36_0
# pytest-doctestplus        0.4.0                      py_0
# pytest-openfiles          0.4.0                      py_0
# pytest-remotedata         0.3.2                    py36_0
# python                    3.6.9                h265db76_0
# python-dateutil           2.8.0                    py36_0
# Python-EasyConfig         0.1.7                     <pip>
# python-editor             1.0.4                     <pip>
# python-libarchive-c       2.8                     py36_13
# pytorch                   1.3.1           py3.6_cuda10.1.243_cudnn7.6.3_0    pytorch
# pytz                      2019.3                     py_0
# pywavelets                1.0.3            py36hdd07704_1
# pyyaml                    5.1.2            py36h7b6447c_0
# pyzmq                     18.1.0           py36he6710b0_0
# qt                        5.9.7                h0c104cb_3    conda-forge
# qtawesome                 0.6.0                      py_0
# qtconsole                 4.5.5                      py_0
# qtpy                      1.9.0                      py_0
# querystring-parser        1.2.4                     <pip>
# readline                  7.0                  h7b6447c_5
# requests                  2.22.0                   py36_0
# requests-oauthlib         1.3.0                     <pip>
# Resource                  0.2.1                     <pip>
# ripgrep                   0.10.0               hc07d326_0
# rope                      0.14.0                     py_0
# rsa                       4.0                       <pip>
# ruamel.yaml               0.15.89                   <pip>
# ruamel_yaml               0.15.46          py36h14c3975_0
# s3transfer                0.2.1                     <pip>
# scikit-image              0.16.2                    <pip>
# scikit-image              0.15.0           py36he6710b0_0
# scikit-learn              0.22             py36hd81dba3_0
# scikit-learn              0.20.3                    <pip>
# scipy                     1.1.0                     <pip>
# scipy                     1.3.1            py36h7c811a0_0
# scrapbook                 0.2.0                     <pip>
# seaborn                   0.9.0                    py36_0
# secretstorage             3.1.1                    py36_0
# send2trash                1.5.0                    py36_0
# setuptools                41.4.0                   py36_0
# setuptools-git            1.2                       <pip>
# shap                      0.29.3                    <pip>
# simplegeneric             0.8.1                    py36_2
# simplejson                3.17.0                    <pip>
# singledispatch            3.4.0.3                  py36_0
# sip                       4.19.8           py36hf484d3e_0
# six                       1.12.0                   py36_0
# six                       1.13.0                    <pip>
# skl2onnx                  1.4.9                     <pip>
# sklearn-pandas            1.7.0                     <pip>
# smart-open                1.9.0                     <pip>
# smmap2                    2.0.5                     <pip>
# snappy                    1.1.7                hbae5bb6_3
# snowballstemmer           2.0.0                      py_0
# sortedcollections         1.1.2                    py36_0
# sortedcontainers          2.1.0                    py36_0
# soupsieve                 1.9.3                    py36_0
# sphinx                    2.2.0                      py_0
# sphinxcontrib             1.0                      py36_1
# sphinxcontrib-applehelp   1.0.1                      py_0
# sphinxcontrib-devhelp     1.0.1                      py_0
# sphinxcontrib-htmlhelp    1.0.2                      py_0
# sphinxcontrib-jsmath      1.0.1                      py_0
# sphinxcontrib-qthelp      1.0.2                      py_0
# sphinxcontrib-serializinghtml 1.1.3                      py_0
# sphinxcontrib-websupport  1.1.2                      py_0
# spyder                    3.3.6                    py36_0
# spyder-kernels            0.5.2                    py36_0
# sqlalchemy                1.3.9            py36h7b6447c_0
# sqlite                    3.30.0               h7b6447c_0
# sqlparse                  0.3.0                     <pip>
# statsmodels               0.10.1           py36hdd07704_0
# sympy                     1.4                      py36_0
# tabulate                  0.8.6                     <pip>
# tbb                       2019.4               hfd86e86_0
# tblib                     1.4.0                      py_0
# tenacity                  6.0.0                     <pip>
# tensorboard               2.1.0                     <pip>
# tensorflow-estimator      2.1.0                     <pip>
# tensorflow-gpu            2.1.0                     <pip>
# termcolor                 1.1.0                     <pip>
# terminado                 0.8.2                    py36_0
# testpath                  0.4.2                    py36_0
# textwrap3                 0.9.2                     <pip>
# tk                        8.6.10               hed695b0_0    conda-forge
# toolz                     0.10.0                     py_0
# torchvision               0.2.1                      py_2    pytorch
# tornado                   6.0.3            py36h7b6447c_0
# tqdm                      4.40.2                     py_0
# traitlets                 4.3.3                    py36_0
# typed-ast                 1.4.0            py36h7b6447c_0
# typing-extensions         3.7.4.1                   <pip>
# unicodecsv                0.14.1                   py36_0
# unixodbc                  2.3.7                h14c3975_0
# urllib3                   1.24.2                   py36_0
# w3lib                     1.21.0                    <pip>
# wcwidth                   0.1.7                    py36_0
# webencodings              0.5.1                    py36_1
# websocket-client          0.57.0                    <pip>
# websockets                8.1                       <pip>
# werkzeug                  0.16.0                     py_0
# Werkzeug                  0.16.1                    <pip>
# wheel                     0.30.0                    <pip>
# wheel                     0.33.6                   py36_0
# widgetsnbextension        3.5.1                    py36_0
# wrapt                     1.11.2           py36h7b6447c_0
# wurlitzer                 1.0.3                    py36_0
# xlrd                      1.2.0                    py36_0
# xlsxwriter                1.2.1                      py_0
# xlwt                      1.3.0                    py36_0
# xorg-kbproto              1.0.7             h14c3975_1002    conda-forge
# xorg-libice               1.0.10               h516909a_0    conda-forge
# xorg-libsm                1.2.3             h84519dc_1000    conda-forge
# xorg-libx11               1.6.9                h516909a_0    conda-forge
# xorg-libxext              1.3.4                h516909a_0    conda-forge
# xorg-libxrender           0.9.10            h516909a_1002    conda-forge
# xorg-renderproto          0.11.1            h14c3975_1002    conda-forge
# xorg-xextproto            7.3.0             h14c3975_1002    conda-forge
# xorg-xproto               7.0.31            h14c3975_1007    conda-forge
# xz                        5.2.4                h14c3975_4
# yaml                      0.1.7                had09818_2
# zeromq                    4.3.1                he6710b0_3
# zict                      1.0.0                      py_0
# zipp                      0.6.0                      py_0
# zlib                      1.2.11               h7b6447c_3
# zstd                      1.3.7                h0b5b093_0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Configure your environment by setting up a Run Configuration

# First, set your libraries here based on your scoring script and your environment file
# Pay attention to the dependencies in your environment file and the packages you use in your script
# If a library is in the conda list, set it as a conda package, otherwise, set it as a pip package
# Always use conda over pip when both are available, as conda takes care of underlying dependencies for you
cd = CondaDependencies.create(conda_packages = ["py-xgboost==0.80","numpy==1.16.2","pandas==0.23.4","psutil==5.6.3", \
                                               "fbprophet==0.5", "scikit-learn==0.20.3","joblib==0.14.1"],
                              pip_packages=["azureml-train-automl-runtime==1.0.85.5","inference-schema", \
                                           "azureml-explain-model==1.0.85","azureml-defaults==1.0.85.1"])

# Create a Run Configuration within a Docker Container and your environment settings by using the code below
amlcompute_run_config = RunConfiguration(conda_dependencies=cd)
amlcompute_run_config.environment.docker.enabled = True
amlcompute_run_config.environment.docker.base_image = DEFAULT_CPU_IMAGE # Use DEFAULT_GPU_IMAGE for Deep Learning Jobs
amlcompute_run_config.environment.python.user_managed_dependencies = False # Set to False in Most Cases

# %% [markdown]
# ### Specify Output Directories and Input Data
# These are simply places in your datastore from where you read and write data.  We use a Data Reference object.
#
# Learn more here:  https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.data.data_reference.datareference?view=azure-ml-py

# %%
# Create an input directory or file path

input_data = DataReference(
    datastore = datastore,
    data_reference_name="ancient_rivers_landing_zone",
    path_on_datastore="test/landing/input"
)

# Create an output directory or file path

scoring_directory = DataReference(
    datastore = datastore,
    data_reference_name="ancient_rivers_scored_zone",
    path_on_datastore="test/scored"
)

# %% [markdown]
# ### Combine everything to create your own Pipeline Configuation using a Custom Python Script
# A Pipeline built using a python script requires a name, a scoring script name, a local path which holds the scoring script, arguments to pass into the scoring script (like your model name, input directory and output directory), a compute target, a list of inputs and a run configuration specifying your environment.<br>  In this case, your inputs are your input and output directories.<br><br>
# The output configuration is only to pass on data in a multi-step pipeline and will be left blank for this step.<br>
#
# For more about Python Script Step configuration settings, click the link below:<br>
# https://docs.microsoft.com/en-us/python/api/azureml-pipeline-steps/azureml.pipeline.steps.python_script_step.pythonscriptstep?view=azure-ml-py

# %%
batch_score_step = PythonScriptStep(
    name="ancient-rivers-scoring-step",
    source_directory = "inference",
    script_name = "ancient-rivers-scoring-script.py",
    arguments= ["--model-name", model_name,
                "--scoring-directory", scoring_directory,
                "--input-data", input_data
               ],
    compute_target=cpu_compute_target,
    inputs=[input_data, scoring_directory],
    #outputs=[output_dir],  # Only necessary if there's another step in the pipeline
    runconfig=amlcompute_run_config
)

# %% [markdown]
# ### Run your Pipeline

# %%
# Create your pipeline
pipeline = Pipeline(workspace=ws, steps=[batch_score_step])
pipeline_run = Experiment(ws, 'ancient-rivers-scoring-pipeline').submit(pipeline,pipeline_parameters={}, show_output=True)
# Out:
# Created step ancient-rivers-scoring-step [5c117d8c][c21a1451-7155-4256-b1ee-bccb12856800], (This step is eligible to reuse a previous run's output)
# Using data reference ancient_rivers_landing_zone for StepId [993106b5][2d9c60f6-6a01-4d6f-baa6-2977460c64e5], (Consumers of this data are eligible to reuse prior runs.)
# Using data reference ancient_rivers_scored_zone for StepId [9886102c][7ad25d16-ef97-40e4-85a9-753e6923a4c7], (Consumers of this data are eligible to reuse prior runs.)
# Submitted PipelineRun 9c415af0-45fc-4c1a-9f7c-f60c717be6a3
# Link to Azure Machine Learning studio: https://ml.azure.com/experiments/ancient-rivers-scoring-pipeline/runs/9c415af0-45fc-4c1a-9f7c-f60c717be6a3?wsid=/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourcegroups/xeek-ancient-rivers/workspaces/ancient-rivers-ml-workspace

# %%
# GUI to see your Pipeline Run
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
# Console logs for your Pipeline
pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 9c415af0-45fc-4c1a-9f7c-f60c717be6a3
# Link to Portal: https://ml.azure.com/experiments/ancient-rivers-scoring-pipeline/runs/9c415af0-45fc-4c1a-9f7c-f60c717be6a3?wsid=/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourcegroups/xeek-ancient-rivers/workspaces/ancient-rivers-ml-workspace
# PipelineRun Status: Running
#
#
# StepRunId: 61a4cb8e-59c4-4fe1-8b55-b770560e3b7f
# Link to Portal: https://ml.azure.com/experiments/ancient-rivers-scoring-pipeline/runs/61a4cb8e-59c4-4fe1-8b55-b770560e3b7f?wsid=/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourcegroups/xeek-ancient-rivers/workspaces/ancient-rivers-ml-workspace
# StepRun( ancient-rivers-scoring-step ) Status: NotStarted
# StepRun( ancient-rivers-scoring-step ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2020/03/01 23:29:24 Downloading source code...
# 2020/03/01 23:29:25 Finished downloading source code
# 2020/03/01 23:29:26 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/03/01 23:29:26 Successfully set up Docker network: acb_default_network
# 2020/03/01 23:29:26 Setting up Docker configuration...
# 2020/03/01 23:29:27 Successfully set up Docker configuration
# 2020/03/01 23:29:27 Logging in to registry: ancientriverd4d046d4.azurecr.io
# 2020/03/01 23:29:28 Successfully logged into ancientriverd4d046d4.azurecr.io
# 2020/03/01 23:29:28 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/03/01 23:29:28 Scanning for dependencies...
# 2020/03/01 23:29:29 Successfully scanned dependencies
# 2020/03/01 23:29:29 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05: Pulling from azureml/base
# Digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#  ---> 93a72e6bd1ce
# Step 2/15 : USER root
#  ---> Running in 8d2581d8d0ef
# Removing intermediate container 8d2581d8d0ef
#  ---> d253e309a340
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 9081f7b8b20c
# Removing intermediate container 9081f7b8b20c
#  ---> 05066ceccd34
# Step 4/15 : WORKDIR /
#  ---> Running in 175920ed64f4
# Removing intermediate container 175920ed64f4
#  ---> e3c0c82b08bd
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> d54cf7372271
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 121f0415a1d1
# Removing intermediate container 121f0415a1d1
#  ---> f28b6cb47981
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 69bad409d98e
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in e5bccd727d27
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# tornado-6.0.3        | 636 KB    |            |   0%
# tornado-6.0.3        | 636 KB    | ########3  |  83%
# tornado-6.0.3        | 636 KB    | ########## | 100%
#
# jpeg-9c              | 251 KB    |            |   0%
# jpeg-9c              | 251 KB    | ########## | 100%
#
# ld_impl_linux-64-2.3 | 589 KB    |            |   0%
# ld_impl_linux-64-2.3 | 589 KB    | #########5 |  96%
# ld_impl_linux-64-2.3 | 589 KB    | ########## | 100%
#
# libxgboost-0.80      | 3.7 MB    |            |   0%
# libxgboost-0.80      | 3.7 MB    | #######6   |  76%
# libxgboost-0.80      | 3.7 MB    | #########8 |  99%
# libxgboost-0.80      | 3.7 MB    | ########## | 100%
#
# libopenblas-0.3.8    | 7.8 MB    |            |   0%
# libopenblas-0.3.8    | 7.8 MB    | ######3    |  64%
# libopenblas-0.3.8    | 7.8 MB    | ########3  |  83%
# libopenblas-0.3.8    | 7.8 MB    | #########7 |  98%
# libopenblas-0.3.8    | 7.8 MB    | ########## | 100%
#
# liblapack-3.8.0      | 10 KB     |            |   0%
# liblapack-3.8.0      | 10 KB     | ########## | 100%
#
# libstdcxx-ng-9.2.0   | 4.5 MB    |            |   0%
# libstdcxx-ng-9.2.0   | 4.5 MB    | #######6   |  76%
# libstdcxx-ng-9.2.0   | 4.5 MB    | #########9 |  99%
# libstdcxx-ng-9.2.0   | 4.5 MB    | ########## | 100%
#
# netcdf4-1.5.1.2      | 537 KB    |            |   0%
# netcdf4-1.5.1.2      | 537 KB    | #########1 |  91%
# netcdf4-1.5.1.2      | 537 KB    | ########## | 100%
#
# certifi-2019.11.28   | 149 KB    |            |   0%
# certifi-2019.11.28   | 149 KB    | ########## | 100%
#
# fbprophet-0.5        | 631 KB    |            |   0%
# fbprophet-0.5        | 631 KB    | #########5 |  96%
# fbprophet-0.5        | 631 KB    | ########## | 100%
#
# gcc_linux-64-7.3.0   | 22 KB     |            |   0%
# gcc_linux-64-7.3.0   | 22 KB     | ########## | 100%
#
# scikit-learn-0.20.3  | 5.8 MB    |            |   0%
# scikit-learn-0.20.3  | 5.8 MB    | ######8    |  68%
# scikit-learn-0.20.3  | 5.8 MB    | ########8  |  89%
# scikit-learn-0.20.3  | 5.8 MB    | ########## | 100%
#
# convertdate-2.1.3    | 30 KB     |            |   0%
# convertdate-2.1.3    | 30 KB     | ########## | 100%
#
# matplotlib-base-3.1. | 6.6 MB    |            |   0%
# matplotlib-base-3.1. | 6.6 MB    | ######5    |  65%
# matplotlib-base-3.1. | 6.6 MB    | ########5  |  85%
# matplotlib-base-3.1. | 6.6 MB    | #########9 | 100%
# matplotlib-base-3.1. | 6.6 MB    | ########## | 100%
#
# pandas-0.23.4        | 9.8 MB    |            |   0%
# pandas-0.23.4        | 9.8 MB    | #####1     |  52%
# pandas-0.23.4        | 9.8 MB    | #######5   |  75%
# pandas-0.23.4        | 9.8 MB    | #########1 |  92%
# pandas-0.23.4        | 9.8 MB    | ########## | 100%
#
# pyparsing-2.4.6      | 59 KB     |            |   0%
# pyparsing-2.4.6      | 59 KB     | ########## | 100%
#
# hdf4-4.2.13          | 964 KB    |            |   0%
# hdf4-4.2.13          | 964 KB    | ########2  |  83%
# hdf4-4.2.13          | 964 KB    | ########## | 100%
#
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# gcc_impl_linux-64-7. | 70.6 MB   |            |   0%
# gcc_impl_linux-64-7. | 70.6 MB   | 8          |   9%
# gcc_impl_linux-64-7. | 70.6 MB   | ##         |  20%
# gcc_impl_linux-64-7. | 70.6 MB   | ###2       |  32%
# gcc_impl_linux-64-7. | 70.6 MB   | ####3      |  44%
# gcc_impl_linux-64-7. | 70.6 MB   | #####5     |  56%
# gcc_impl_linux-64-7. | 70.6 MB   | ######7    |  68%
# gcc_impl_linux-64-7. | 70.6 MB   | #######8   |  78%
# gcc_impl_linux-64-7. | 70.6 MB   | ########5  |  86%
# gcc_impl_linux-64-7. | 70.6 MB   | #########  |  91%
# gcc_impl_linux-64-7. | 70.6 MB   | #########4 |  95%
# gcc_impl_linux-64-7. | 70.6 MB   | #########7 |  97%
# gcc_impl_linux-64-7. | 70.6 MB   | #########9 |  99%
# gcc_impl_linux-64-7. | 70.6 MB   | ########## | 100%
#
# libgcc-ng-9.2.0      | 8.2 MB    |            |   0%
# libgcc-ng-9.2.0      | 8.2 MB    | ######5    |  66%
# libgcc-ng-9.2.0      | 8.2 MB    | ########5  |  85%
# libgcc-ng-9.2.0      | 8.2 MB    | ########## | 100%
#
# py-xgboost-0.80      | 62 KB     |            |   0%
# py-xgboost-0.80      | 62 KB     | ########## | 100%
#
# cycler-0.10.0        | 9 KB      |            |   0%
# cycler-0.10.0        | 9 KB      | ########## | 100%
#
# setuptools-45.2.0    | 653 KB    |            |   0%
# setuptools-45.2.0    | 653 KB    | ########4  |  85%
# setuptools-45.2.0    | 653 KB    | ########## | 100%
#
# pystan-2.19.1.1      | 17.2 MB   |            |   0%
# pystan-2.19.1.1      | 17.2 MB   | ###1       |  31%
# pystan-2.19.1.1      | 17.2 MB   | #######4   |  74%
# pystan-2.19.1.1      | 17.2 MB   | #########4 |  94%
#
# pystan-2.19.1.1      | 17.2 MB   | ########## | 100%
#
# six-1.14.0           | 23 KB     |            |   0%
# six-1.14.0           | 23 KB     | ########## | 100%
#
# hdf5-1.10.4          | 5.3 MB    |            |   0%
# hdf5-1.10.4          | 5.3 MB    | #######5   |  75%
# hdf5-1.10.4          | 5.3 MB    | #########7 |  98%
# hdf5-1.10.4          | 5.3 MB    | ########## | 100%
#
# sqlite-3.20.1        | 1.3 MB    |            |   0%
# sqlite-3.20.1        | 1.3 MB    | ########   |  81%
# sqlite-3.20.1        | 1.3 MB    | ########## | 100%
# libgomp-9.2.0        | 816 KB    |            |   0%
# libgomp-9.2.0        | 816 KB    | #########5 |  95%
# libgomp-9.2.0        | 816 KB    | ########## | 100%
#
# libcblas-3.8.0       | 10 KB     |            |   0%
# libcblas-3.8.0       | 10 KB     | ########## | 100%
#
# freetype-2.10.0      | 884 KB    |            |   0%
# freetype-2.10.0      | 884 KB    | ########5  |  86%
# freetype-2.10.0      | 884 KB    | ########## | 100%
#
# binutils_impl_linux- | 9.1 MB    |            |   0%
# binutils_impl_linux- | 9.1 MB    | #####5     |  55%
# binutils_impl_linux- | 9.1 MB    | #######6   |  76%
# binutils_impl_linux- | 9.1 MB    | #########3 |  93%
# binutils_impl_linux- | 9.1 MB    | ########## | 100%
#
# ncurses-6.0          | 920 KB    |            |   0%
# ncurses-6.0          | 920 KB    | #######9   |  79%
# ncurses-6.0          | 920 KB    | ########9  |  90%
# ncurses-6.0          | 920 KB    | ########## | 100%
#
# numpy-1.16.2         | 4.3 MB    |            |   0%
# numpy-1.16.2         | 4.3 MB    | #######6   |  76%
# numpy-1.16.2         | 4.3 MB    | #########  |  91%
# numpy-1.16.2         | 4.3 MB    | ########## | 100%
#
# libssh2-1.8.0        | 246 KB    |            |   0%
# libssh2-1.8.0        | 246 KB    | #########7 |  98%
# libssh2-1.8.0        | 246 KB    | ########## | 100%
#
# psutil-5.6.3         | 322 KB    |            |   0%
# psutil-5.6.3         | 322 KB    | #########6 |  96%
# psutil-5.6.3         | 322 KB    | ########## | 100%
#
# llvm-openmp-9.0.1    | 782 KB    |            |   0%
# llvm-openmp-9.0.1    | 782 KB    | #########1 |  91%
# llvm-openmp-9.0.1    | 782 KB    | ########## | 100%
#
# kiwisolver-1.1.0     | 86 KB     |            |   0%
# kiwisolver-1.1.0     | 86 KB     | ########## | 100%
#
# openssl-1.0.2u       | 3.2 MB    |            |   0%
# openssl-1.0.2u       | 3.2 MB    | #######6   |  76%
# openssl-1.0.2u       | 3.2 MB    | #########7 |  98%
# openssl-1.0.2u       | 3.2 MB    | ########## | 100%
#
# binutils_linux-64-2. | 21 KB     |            |   0%
# binutils_linux-64-2. | 21 KB     | ########## | 100%
#
# ephem-3.7.7.1        | 722 KB    |            |   0%
# ephem-3.7.7.1        | 722 KB    | ########6  |  86%
# ephem-3.7.7.1        | 722 KB    | ########## | 100%
#
# gxx_impl_linux-64-7. | 19.1 MB   |            |   0%
# gxx_impl_linux-64-7. | 19.1 MB   | ##5        |  26%
# gxx_impl_linux-64-7. | 19.1 MB   | ######6    |  66%
# gxx_impl_linux-64-7. | 19.1 MB   | ########3  |  84%
# gxx_impl_linux-64-7. | 19.1 MB   | #########6 |  96%
# gxx_impl_linux-64-7. | 19.1 MB   | ########## | 100%
#
# lunardate-0.2.0      | 21 KB     |            |   0%
# lunardate-0.2.0      | 21 KB     | ########## | 100%
#
# curl-7.61.0          | 859 KB    |            |   0%
# curl-7.61.0          | 859 KB    | #######8   |  78%
# curl-7.61.0          | 859 KB    | #########  |  91%
# curl-7.61.0          | 859 KB    | ########## | 100%
#
# pytz-2019.3          | 237 KB    |            |   0%
# pytz-2019.3          | 237 KB    | #########4 |  94%
# pytz-2019.3          | 237 KB    | ########## | 100%
#
# cython-0.29.15       | 2.2 MB    |            |   0%
# cython-0.29.15       | 2.2 MB    | #######7   |  77%
# cython-0.29.15       | 2.2 MB    | #########2 |  93%
# cython-0.29.15       | 2.2 MB    | ########## | 100%
#
# python-dateutil-2.8. | 220 KB    |            |   0%
# python-dateutil-2.8. | 220 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# gxx_linux-64-7.3.0   | 21 KB     |            |   0%
# gxx_linux-64-7.3.0   | 21 KB     | ########## | 100%
#
# libpng-1.6.37        | 343 KB    |            |   0%
# libpng-1.6.37        | 343 KB    | ########## | 100%
#
# readline-7.0         | 1.1 MB    |            |   0%
# readline-7.0         | 1.1 MB    | ########2  |  82%
# readline-7.0         | 1.1 MB    | ########## | 100%
#
# packaging-20.1       | 31 KB     |            |   0%
# packaging-20.1       | 31 KB     | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | #######6   |  77%
# tk-8.6.10            | 3.2 MB    | #########9 | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# scipy-1.4.1          | 18.9 MB   |            |   0%
# scipy-1.4.1          | 18.9 MB   | ##9        |  29%
# scipy-1.4.1          | 18.9 MB   | ######3    |  63%
# scipy-1.4.1          | 18.9 MB   | #######9   |  80%
# scipy-1.4.1          | 18.9 MB   | #########2 |  92%
# scipy-1.4.1          | 18.9 MB   | ########## | 100%
#
# _openmp_mutex-4.5    | 5 KB      |            |   0%
# _openmp_mutex-4.5    | 5 KB      | ########## | 100%
#
# cftime-1.0.4.2       | 312 KB    |            |   0%
# cftime-1.0.4.2       | 312 KB    | ########## | 100%
#
# zlib-1.2.11          | 105 KB    |            |   0%
# zlib-1.2.11          | 105 KB    | ########## | 100%
#
# libblas-3.8.0        | 10 KB     |            |   0%
# libblas-3.8.0        | 10 KB     | ########## | 100%
#
# krb5-1.14.6          | 4.0 MB    |            |   0%
# krb5-1.14.6          | 4.0 MB    | #######6   |  76%
# krb5-1.14.6          | 4.0 MB    | #########3 |  94%
# krb5-1.14.6          | 4.0 MB    | ########## | 100%
#
# pip-20.0.2           | 1.0 MB    |            |   0%
# pip-20.0.2           | 1.0 MB    | #######9   |  80%
# pip-20.0.2           | 1.0 MB    | #########4 |  95%
# pip-20.0.2           | 1.0 MB    | ########## | 100%
#
# bzip2-1.0.8          | 396 KB    |            |   0%
# bzip2-1.0.8          | 396 KB    | ########## | 100%
#
# libffi-3.2.1         | 46 KB     |            |   0%
# libffi-3.2.1         | 46 KB     | ########## | 100%
#
# joblib-0.14.1        | 198 KB    |            |   0%
# joblib-0.14.1        | 198 KB    | ########## | 100%
#
# icu-64.2             | 12.6 MB   |            |   0%
# icu-64.2             | 12.6 MB   | #####1     |  52%
# icu-64.2             | 12.6 MB   | #######5   |  75%
# icu-64.2             | 12.6 MB   | #########2 |  93%
# icu-64.2             | 12.6 MB   | ########## | 100%
#
# xarray-0.13.0        | 435 KB    |            |   0%
# xarray-0.13.0        | 435 KB    | ########9  |  89%
# xarray-0.13.0        | 435 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##         |  20%
# python-3.6.2         | 27.0 MB   | ####9      |  50%
# python-3.6.2         | 27.0 MB   | ######6    |  67%
# python-3.6.2         | 27.0 MB   | ########   |  81%
# python-3.6.2         | 27.0 MB   | #########1 |  91%
# python-3.6.2         | 27.0 MB   | #########8 |  99%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# holidays-0.9.11      | 39 KB     |            |   0%
# holidays-0.9.11      | 39 KB     | ########## | 100%
#
# ca-certificates-2019 | 145 KB    |            |   0%
# ca-certificates-2019 | 145 KB    | ########## | 100%
#
# libnetcdf-4.6.2      | 1.3 MB    |            |   0%
# libnetcdf-4.6.2      | 1.3 MB    | ########1  |  82%
# libnetcdf-4.6.2      | 1.3 MB    | ########## | 100%
#
# arviz-0.6.1          | 1.3 MB    |            |   0%
# arviz-0.6.1          | 1.3 MB    | #######7   |  78%
# arviz-0.6.1          | 1.3 MB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.7 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.7 MB    | #######9   |  79%
# libgfortran-ng-7.3.0 | 1.7 MB    | ########## | 100%
#
# wheel-0.34.2         | 24 KB     |            |   0%
# wheel-0.34.2         | 24 KB     | ########## | 100%
#
# _py-xgboost-mutex-2. | 8 KB      |            |   0%
# _py-xgboost-mutex-2. | 8 KB      | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
# done
# Collecting azureml-train-automl-runtime==1.0.85.5
#   Downloading azureml_train_automl_runtime-1.0.85.5-py3-none-any.whl (77 kB)
# Collecting inference-schema
#   Downloading inference_schema-1.0.1-py3-none-any.whl (18 kB)
# Collecting azureml-explain-model==1.0.85
#   Downloading azureml_explain_model-1.0.85-py3-none-any.whl (22 kB)
# Collecting azureml-defaults==1.0.85.1
#   Downloading azureml_defaults-1.0.85.1-py2.py3-none-any.whl (3.0 kB)
# Collecting sklearn-pandas<=1.7.0,>=1.4.0
#   Downloading sklearn_pandas-1.7.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.0.85.5->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 1)) (2019.3)
# Collecting azureml-automl-runtime==1.0.85.*
#   Downloading azureml_automl_runtime-1.0.85.5-py3-none-any.whl (1.9 MB)
# Collecting resource>=0.1.8
#   Downloading Resource-0.2.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy<=1.16.2,>=1.16.0 in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.0.85.5->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 1)) (1.16.2)
# Collecting azureml-train-automl-client==1.0.85.*
#   Downloading azureml_train_automl_client-1.0.85.4-py3-none-any.whl (69 kB)
# Collecting azureml-core==1.0.85.*
#   Downloading azureml_core-1.0.85.5-py2.py3-none-any.whl (1.2 MB)
# Collecting onnx>=1.5.0
#   Downloading onnx-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (4.8 MB)
# Collecting skl2onnx==1.4.9
#   Downloading skl2onnx-1.4.9-py2.py3-none-any.whl (114 kB)
# Collecting scipy<=1.1.0,>=1.0.0
#   Downloading scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2 MB)
# Collecting azureml-dataprep[fuse,pandas]<1.2.0a,>=1.1.37a
#   Downloading azureml_dataprep-1.1.38-py3-none-any.whl (26.9 MB)
# Requirement already satisfied: pandas<=0.23.4,>=0.21.0 in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.0.85.5->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 1)) (0.23.4)
# Collecting onnxconverter-common<=1.6.0,>=1.4.2
#   Downloading onnxconverter_common-1.6.0-py2.py3-none-any.whl (43 kB)
# Collecting gensim
#   Downloading gensim-3.8.1-cp36-cp36m-manylinux1_x86_64.whl (24.2 MB)
# Collecting statsmodels<=0.10.2,>=0.9.0
#   Downloading statsmodels-0.10.2-cp36-cp36m-manylinux1_x86_64.whl (8.1 MB)
# Collecting lightgbm<=2.3.0,>=2.0.11
#   Downloading lightgbm-2.3.0-py2.py3-none-manylinux1_x86_64.whl (1.3 MB)
# Collecting azureml-telemetry==1.0.85.*
#   Downloading azureml_telemetry-1.0.85.2-py3-none-any.whl (29 kB)
# Requirement already satisfied: scikit-learn<=0.20.3,>=0.19.0 in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.0.85.5->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 1)) (0.20.3)
# Collecting onnxmltools==1.4.1
#   Downloading onnxmltools-1.4.1-py2.py3-none-any.whl (371 kB)
# Collecting dill>=0.2.8
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
# Collecting patsy>=0.5.1
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Collecting azureml-automl-core==1.0.85.*
#   Downloading azureml_automl_core-1.0.85.5-py3-none-any.whl (102 kB)
# Collecting wheel==0.30.0
#   Downloading wheel-0.30.0-py2.py3-none-any.whl (49 kB)
# Collecting azureml-pipeline-core==1.0.85.*
#   Downloading azureml_pipeline_core-1.0.85.1-py2.py3-none-any.whl (269 kB)
# Collecting wrapt==1.11.1
#   Downloading wrapt-1.11.1.tar.gz (27 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from inference-schema->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 2)) (2.8.1)
# Collecting azureml-interpret==1.0.85.*
#   Downloading azureml_interpret-1.0.85-py3-none-any.whl (35 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting pmdarima==1.1.1
#   Downloading pmdarima-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (682 kB)
# Requirement already satisfied: psutil<6.0.0,>=5.2.2 in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from azureml-automl-runtime==1.0.85.*->azureml-train-automl-runtime==1.0.85.5->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 1)) (5.6.3)
# Collecting py-cpuinfo
#   Downloading py-cpuinfo-5.0.0.tar.gz (82 kB)
# Collecting nimbusml>=1.5.0
#   Downloading nimbusml-1.6.1-cp36-none-manylinux1_x86_64.whl (105.2 MB)
# Collecting JsonSir>=0.0.2
#   Downloading JsonSir-0.0.2.tar.gz (2.2 kB)
# Collecting JsonForm>=0.0.2
#   Downloading JsonForm-0.0.2.tar.gz (2.4 kB)
# Collecting python-easyconfig>=0.1.0
#   Downloading Python_EasyConfig-0.1.7-py2.py3-none-any.whl (5.4 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.11-py2.py3-none-any.whl (83 kB)
# Collecting jmespath
#   Downloading jmespath-0.9.5-py2.py3-none-any.whl (24 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.2-py2.py3-none-any.whl (53 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-7.2.0-py2.py3-none-any.whl (519 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-8.0.1-py2.py3-none-any.whl (758 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting docker
#   Downloading docker-4.2.0-py2.py3-none-any.whl (143 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting pathspec
#   Downloading pathspec-0.7.0-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from azureml-core==1.0.85.*->azureml-train-automl-runtime==1.0.85.5->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 1)) (1.14.0)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.24-py2.py3-none-any.whl (12 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.8-cp34-abi3-manylinux2010_x86_64.whl (2.3 MB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting ruamel.yaml<=0.15.89,>=0.15.35
#   Downloading ruamel.yaml-0.15.89-cp36-cp36m-manylinux1_x86_64.whl (651 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.1.1-py2.py3-none-any.whl (117 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.3-py2.py3-none-any.whl (32 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.2-py2.py3-none-any.whl (40 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting protobuf
#   Downloading protobuf-3.11.3-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting typing-extensions>=3.6.2.1
#   Downloading typing_extensions-3.7.4.1-py3-none-any.whl (20 kB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.3.0-py2.py3-none-any.whl (26 kB)
# Collecting dotnetcore2>=2.1.9
#   Downloading dotnetcore2-2.1.13-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azureml-dataprep-native<14.0.0,>=13.2.0
#   Downloading azureml_dataprep_native-13.2.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting pyarrow==0.15.*; extra == "pandas"
#   Downloading pyarrow-0.15.1-cp36-cp36m-manylinux2010_x86_64.whl (59.2 MB)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-1.9.0.tar.gz (70 kB)
# Collecting keras2onnx
#   Downloading keras2onnx-1.6.0-py3-none-any.whl (219 kB)
# Collecting interpret-community==0.4.*
#   Downloading interpret_community-0.4.1-py3-none-any.whl (23.4 MB)
# Collecting click>=5.1
#   Downloading Click-7.0-py2.py3-none-any.whl (81 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.1-py2.py3-none-any.whl (126 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Requirement already satisfied: Cython>=0.29 in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from pmdarima==1.1.1->azureml-automl-runtime==1.0.85.*->azureml-train-automl-runtime==1.0.85.5->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 1)) (0.29.15)
# Collecting jsonschema
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting PyYAML
#   Downloading PyYAML-5.3.tar.gz (268 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core==1.0.85.*->azureml-train-automl-runtime==1.0.85.5->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 1)) (2019.11.28)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.2-py3-none-any.whl (21 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: setuptools in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from protobuf->onnx>=1.5.0->azureml-train-automl-runtime==1.0.85.5->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 1)) (45.2.0.post20200209)
# Collecting distro>=1.2.0
#   Downloading distro-1.4.0-py2.py3-none-any.whl (17 kB)
# Collecting boto>=2.32
#   Downloading boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
# Collecting boto3
#   Downloading boto3-1.12.11-py2.py3-none-any.whl (128 kB)
# Collecting fire
#   Downloading fire-0.2.1.tar.gz (76 kB)
# Collecting interpret-core[required]==0.1.19
#   Downloading interpret_core-0.1.19-py3-none-any.whl (7.8 MB)
# Collecting shap<=0.33.0,>=0.20.0
#   Downloading shap-0.33.0.tar.gz (263 kB)
# Requirement already satisfied: packaging in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from interpret-community==0.4.*->azureml-interpret==1.0.85.*->azureml-explain-model==1.0.85->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 3)) (20.1)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-19.3.0-py2.py3-none-any.whl (39 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-1.5.0-py2.py3-none-any.whl (30 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.15.7.tar.gz (107 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.19.tar.gz (158 kB)
# Collecting botocore<1.16.0,>=1.15.11
#   Downloading botocore-1.15.11-py2.py3-none-any.whl (5.9 MB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: joblib>=0.11; extra == "required" in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from interpret-core[required]==0.1.19->interpret-community==0.4.*->azureml-interpret==1.0.85.*->azureml-explain-model==1.0.85->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 3)) (0.14.1)
# Collecting tqdm>4.25.0
#   Downloading tqdm-4.43.0-py2.py3-none-any.whl (59 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/python3.6/site-packages (from packaging->interpret-community==0.4.*->azureml-interpret==1.0.85.*->azureml-explain-model==1.0.85->-r /azureml-environment-setup/condaenv.15e5y0x8.requirements.txt (line 3)) (2.4.6)
# Collecting zipp>=0.5
#   Downloading zipp-3.0.0-py3-none-any.whl (4.8 kB)
# Collecting docutils<0.16,>=0.10
#   Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
# Building wheels for collected packages: dill, wrapt, json-logging-py, py-cpuinfo, JsonSir, JsonForm, fusepy, smart-open, liac-arff, PyYAML, fire, shap, pyrsistent, pycparser, termcolor
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78530 sha256=42b0eb748372e355f9d1a4d4907733045ce4ad5446aa1c5a1bcf883072f40baf
#   Stored in directory: /root/.cache/pip/wheels/09/84/74/d2b4feb9ac9488bc83c475cb2cbe8e8b7d9cea8320d32f3787
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.11.1-cp36-cp36m-linux_x86_64.whl size=66705 sha256=b072bfab4247c5963312c11da38666af7493a63076183d860634c08e31ec4f36
#   Stored in directory: /root/.cache/pip/wheels/94/0f/ec/66085641573800014bb0c8b657f3366eff641c42df79abbfe9
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=ac6cee9450728c9559c4fc652649298fda5a1fc993d1c0c08fbe990b2dc97085
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for py-cpuinfo (setup.py): started
#   Building wheel for py-cpuinfo (setup.py): finished with status 'done'
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-5.0.0-py3-none-any.whl size=18682 sha256=095ad108bbd49cf82b0b9c99a9fbe8dcf3b2cfc2486266cad6c3f7efad4a681b
#   Stored in directory: /root/.cache/pip/wheels/e6/54/db/65176a1697a583d8ec5f90510f6faab11cda739d0e4f0ba2ea
#   Building wheel for JsonSir (setup.py): started
#   Building wheel for JsonSir (setup.py): finished with status 'done'
#   Created wheel for JsonSir: filename=JsonSir-0.0.2-py3-none-any.whl size=4774 sha256=ee7dd07cc37a293e97649dae10253d5dcad79bd3f2743e1a401727c5eb13bd9a
#   Stored in directory: /root/.cache/pip/wheels/05/42/c2/d3cd8ea9f896260294ea5fbeb985905e81654b670d7753a419
#   Building wheel for JsonForm (setup.py): started
#   Building wheel for JsonForm (setup.py): finished with status 'done'
#   Created wheel for JsonForm: filename=JsonForm-0.0.2-py3-none-any.whl size=3325 sha256=d7a501331d5fe2eb8f0460567f0829780df00809a82bcd8a222454842ee822a6
#   Stored in directory: /root/.cache/pip/wheels/15/f9/2d/61747ec74e70a079a428c54fc1167b03a4198a2e2ac4be5f07
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=a5a828d5b52ba48bdf971b03fbda0aa9e2898e21cc968881637dff89b0bfd323
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-1.9.0-py3-none-any.whl size=73085 sha256=e54f6420ee3a7a0ed8b519b7da6793cb72c9540779edd4c4dc8f266203c771de
#   Stored in directory: /root/.cache/pip/wheels/8e/9f/cd/dbf5c1362c59abb699a218c1151679033b8ccb5b6db559d512
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=0f40a53822b52ea56d560c9aec9cbf345c62342c356677b63956f492377af51c
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
#   Building wheel for PyYAML (setup.py): started
#   Building wheel for PyYAML (setup.py): finished with status 'done'
#   Created wheel for PyYAML: filename=PyYAML-5.3-cp36-cp36m-linux_x86_64.whl size=44229 sha256=e87eb35b2aa44671bf673af1d9e583f81ee2c55935452c3560e8382a30aaf3c7
#   Stored in directory: /root/.cache/pip/wheels/b1/86/0d/10e6c39d3a2b85ba807d7657ee80f08cc16c03f2aa2adf8e46
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.2.1-py2.py3-none-any.whl size=103528 sha256=eb43222b73c4bb16c8599b925402bfd331f536b30c777d1925967cf725e79b00
#   Stored in directory: /root/.cache/pip/wheels/8b/ea/12/2a424b5baadd1b278dc438c45aa492588dbfd900832c8e733a
#   Building wheel for shap (setup.py): started
#   Building wheel for shap (setup.py): finished with status 'done'
#   Created wheel for shap: filename=shap-0.33.0-cp36-cp36m-linux_x86_64.whl size=386908 sha256=0b4fce4af349f2461bcea5f08165232965c4ac921b96ff6d3380990fca5ce25e
#   Stored in directory: /root/.cache/pip/wheels/bd/22/0e/5a588542d1139b965493dab410d0772b4f65ae50c6d5916545
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.15.7-cp36-cp36m-linux_x86_64.whl size=113374 sha256=da885f52e215ba8069921c5dacd3205b9492fc4dc9b435a09b472abfb3566e3e
#   Stored in directory: /root/.cache/pip/wheels/43/9a/e4/7f687f2bb934e9a26a6e1158778ed7c5436b9ea15db48c888a
#   Building wheel for pycparser (setup.py): started
#   Building wheel for pycparser (setup.py): finished with status 'done'
#   Created wheel for pycparser: filename=pycparser-2.19-py2.py3-none-any.whl size=111031 sha256=e2266a9becedc527a8f60a72c52ebca598746d81b0408c8bb6562464f96ec416
#   Stored in directory: /root/.cache/pip/wheels/c6/6b/83/2608afaa57ecfb0a66ac89191a8d9bad71c62ca55ee499c2d0
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=ccbf52bacb4f9a54180bc095f04b27ef4a43d3fe5157cb7340fff0f5e4156ce1
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
# Successfully built dill wrapt json-logging-py py-cpuinfo JsonSir JsonForm fusepy smart-open liac-arff PyYAML fire shap pyrsistent pycparser termcolor
# Installing collected packages: scipy, sklearn-pandas, patsy, statsmodels, pmdarima, JsonSir, attrs, zipp, importlib-metadata, pyrsistent, jsonschema, JsonForm, PyYAML, python-easyconfig, resource, protobuf, typing-extensions, onnx, onnxconverter-common, skl2onnx, cloudpickle, distro, dotnetcore2, azureml-dataprep-native, fusepy, pyarrow, azureml-dataprep, boto, idna, chardet, urllib3, requests, docutils, jmespath, botocore, s3transfer, boto3, smart-open, gensim, lightgbm, termcolor, fire, keras2onnx, onnxmltools, dill, azureml-automl-core, py-cpuinfo, wheel, nimbusml, azureml-automl-runtime, oauthlib, requests-oauthlib, isodate, msrest, contextlib2, pycparser, cffi, cryptography, PyJWT, adal, msrestazure, azure-common, azure-mgmt-storage, azure-mgmt-resource, jeepney, SecretStorage, azure-mgmt-containerregistry, azure-mgmt-authorization, websocket-client, docker, pathspec, pyopenssl, azure-graphrbac, pyasn1, ndg-httpsclient, ruamel.yaml, azure-mgmt-keyvault, jsonpickle, backports.weakref, backports.tempfile, azureml-core, applicationinsights, azureml-telemetry, azureml-train-automl-client, click, MarkupSafe, Jinja2, itsdangerous, werkzeug, flask, gunicorn, configparser, liac-arff, azureml-model-management-sdk, json-logging-py, azureml-defaults, azureml-pipeline-core, azureml-train-automl-runtime, wrapt, inference-schema, interpret-core, tqdm, shap, interpret-community, azureml-interpret, azureml-explain-model
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.34.2
#     Uninstalling wheel-0.34.2:
#       Successfully uninstalled wheel-0.34.2
# Successfully installed Jinja2-2.11.1 JsonForm-0.0.2 JsonSir-0.0.2 MarkupSafe-1.1.1 PyJWT-1.7.1 PyYAML-5.3 SecretStorage-3.1.2 adal-1.2.2 applicationinsights-0.11.9 attrs-19.3.0 azure-common-1.1.24 azure-graphrbac-0.61.1 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.1.1 azure-mgmt-resource-8.0.1 azure-mgmt-storage-7.2.0 azureml-automl-core-1.0.85.5 azureml-automl-runtime-1.0.85.5 azureml-core-1.0.85.5 azureml-dataprep-1.1.38 azureml-dataprep-native-13.2.0 azureml-defaults-1.0.85.1 azureml-explain-model-1.0.85 azureml-interpret-1.0.85 azureml-model-management-sdk-1.0.1b6.post1 azureml-pipeline-core-1.0.85.1 azureml-telemetry-1.0.85.2 azureml-train-automl-client-1.0.85.4 azureml-train-automl-runtime-1.0.85.5 backports.tempfile-1.0 backports.weakref-1.0.post1 boto-2.49.0 boto3-1.12.11 botocore-1.15.11 cffi-1.14.0 chardet-3.0.4 click-7.0 cloudpickle-1.3.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-2.8 dill-0.3.1.1 distro-1.4.0 docker-4.2.0 docutils-0.15.2 dotnetcore2-2.1.13 fire-0.2.1 flask-1.0.3 fusepy-3.0.1 gensim-3.8.1 gunicorn-19.9.0 idna-2.9 importlib-metadata-1.5.0 inference-schema-1.0.1 interpret-community-0.4.1 interpret-core-0.1.19 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.2 jmespath-0.9.5 json-logging-py-0.2 jsonpickle-1.3 jsonschema-3.2.0 keras2onnx-1.6.0 liac-arff-2.4.0 lightgbm-2.3.0 msrest-0.6.11 msrestazure-0.6.2 ndg-httpsclient-0.5.1 nimbusml-1.6.1 oauthlib-3.1.0 onnx-1.6.0 onnxconverter-common-1.6.0 onnxmltools-1.4.1 pathspec-0.7.0 patsy-0.5.1 pmdarima-1.1.1 protobuf-3.11.3 py-cpuinfo-5.0.0 pyarrow-0.15.1 pyasn1-0.4.8 pycparser-2.19 pyopenssl-19.1.0 pyrsistent-0.15.7 python-easyconfig-0.1.7 requests-2.23.0 requests-oauthlib-1.3.0 resource-0.2.1 ruamel.yaml-0.15.89 s3transfer-0.3.3 scipy-1.1.0 shap-0.33.0 skl2onnx-1.4.9 sklearn-pandas-1.7.0 smart-open-1.9.0 statsmodels-0.10.2 termcolor-1.1.0 tqdm-4.43.0 typing-extensions-3.7.4.1 urllib3-1.25.8 websocket-client-0.57.0 werkzeug-0.16.1 wheel-0.30.0 wrapt-1.11.1 zipp-3.0.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Removing intermediate container e5bccd727d27
#  ---> cc3fb0264c48
# Step 9/15 : ENV PATH /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/bin:$PATH
#  ---> Running in 57b75fa5c030
# Removing intermediate container 57b75fa5c030
#  ---> 7c6e7a735a24
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd
#  ---> Running in 32c4a7ff8a4c
# Removing intermediate container 32c4a7ff8a4c
#  ---> d28cf8f47075
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib:$LD_LIBRARY_PATH
#  ---> Running in e788b0cf79d0
# Removing intermediate container e788b0cf79d0
#  ---> 333d9458c6a0
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 898d749651d4
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "[]" /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 3e7a8e2a6fa2
# Removing intermediate container 3e7a8e2a6fa2
#  ---> e16567166c6b
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 392b74b83bc8
# Removing intermediate container 392b74b83bc8
#  ---> 864d15c2683e
# Step 15/15 : CMD ["bash"]
#  ---> Running in 8c85e865619c
# Removing intermediate container 8c85e865619c
#  ---> 2f6e83ea9af5
# Successfully built 2f6e83ea9af5
# Successfully tagged ancientriverd4d046d4.azurecr.io/azureml/azureml_2c6e63ed5158ba5dbcb9b13d72e8814a:latest
# 2020/03/01 23:36:00 Successfully executed container: acb_step_0
# 2020/03/01 23:36:00 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/03/01 23:36:00 Pushing image: ancientriverd4d046d4.azurecr.io/azureml/azureml_2c6e63ed5158ba5dbcb9b13d72e8814a:latest, attempt 1
# The push refers to repository [ancientriverd4d046d4.azurecr.io/azureml/azureml_2c6e63ed5158ba5dbcb9b13d72e8814a]
# f68718162768: Preparing
# 9d5605346db8: Preparing
# c5c09927c048: Preparing
# 5a066bb6e4f4: Preparing
# e956152874fa: Preparing
# 5416d7bb77df: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# 5416d7bb77df: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# f68718162768: Pushed
# e956152874fa: Pushed
# c5c09927c048: Pushed
# 5a066bb6e4f4: Pushed
# 5416d7bb77df: Pushed
# e1171d4d60ca: Pushed
# 6ef1a8ae63b7: Pushed
#
# 340dc32eb998: Pushed
# f2608f66a0e3: Pushed
# ccdb13a20bf2: Pushed
# 9513cdf4e497: Pushed
# 0e259b09e5f4: Pushed
# 85389f9ead9e: Pushed
# 7f083f9454c0: Pushed
#
# df18b66efaa6: Pushed
# 29f36b5893dc: Pushed
#
# 9d5605346db8: Pushed
# latest: digest: sha256:ba8c032ab3170703276b11fed1c04ed13f9a5858f9ae0b8e710cb1429551f24e size: 3883
# 2020/03/01 23:38:53 Successfully pushed image: ancientriverd4d046d4.azurecr.io/azureml/azureml_2c6e63ed5158ba5dbcb9b13d72e8814a:latest
# 2020/03/01 23:38:53 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 391.604050)
# 2020/03/01 23:38:53 Populating digests for step ID: acb_step_0...
# 2020/03/01 23:38:55 Successfully populated digests for step ID: acb_step_0
# 2020/03/01 23:38:55 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 173.560453)
# 2020/03/01 23:38:55 The following dependencies were found:
# 2020/03/01 23:38:55
# - image:
#     registry: ancientriverd4d046d4.azurecr.io
#     repository: azureml/azureml_2c6e63ed5158ba5dbcb9b13d72e8814a
#     tag: latest
#     digest: sha256:ba8c032ab3170703276b11fed1c04ed13f9a5858f9ae0b8e710cb1429551f24e
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
#
#
# Run ID: cay was successful after 9m32s
# Streaming azureml-logs/55_azureml-execution-tvmps_2a4a06821f6562f35440589203c0af982a1395217a9f15d07b9ef55f716c56e7_d.txt
# ========================================================================================================================
# 2020-03-01T23:45:30Z Starting output-watcher...
# 2020-03-01T23:45:30Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_2c6e63ed5158ba5dbcb9b13d72e8814a
# a1298f4ce990: Pulling fs layer
# 04a3282d9c4b: Pulling fs layer
# 9b0d3db6dc03: Pulling fs layer
# 8269c605f3f1: Pulling fs layer
# 6504d449e70c: Pulling fs layer
# 4e38f320d0d4: Pulling fs layer
# b0a763e8ee03: Pulling fs layer
# 11917a028ca4: Pulling fs layer
# a6c378d11cbf: Pulling fs layer
# 6cc007ad9140: Pulling fs layer
# 6c1698a608f3: Pulling fs layer
# 1460a62ff947: Pulling fs layer
# a9c966eafa61: Pulling fs layer
# 0b4c4154ff8b: Pulling fs layer
# 333603dc44f9: Pulling fs layer
# e8f479870769: Pulling fs layer
# bd12bd79bfb9: Pulling fs layer
# 6cc007ad9140: Waiting
# 1460a62ff947: Waiting
# a9c966eafa61: Waiting
# 6c1698a608f3: Waiting
# 8269c605f3f1: Waiting
# e8f479870769: Waiting
# 4e38f320d0d4: Waiting
# b0a763e8ee03: Waiting
# 0b4c4154ff8b: Waiting
# 333603dc44f9: Waiting
# a6c378d11cbf: Waiting
# 04a3282d9c4b: Verifying Checksum
# 04a3282d9c4b: Download complete
# 9b0d3db6dc03: Verifying Checksum
# 9b0d3db6dc03: Download complete
# 8269c605f3f1: Verifying Checksum
# 8269c605f3f1: Download complete
# a1298f4ce990: Verifying Checksum
# a1298f4ce990: Download complete
# 4e38f320d0d4: Verifying Checksum
# 4e38f320d0d4: Download complete
# 6504d449e70c: Verifying Checksum
# 6504d449e70c: Download complete
# b0a763e8ee03: Verifying Checksum
# b0a763e8ee03: Download complete
# 11917a028ca4: Verifying Checksum
# 11917a028ca4: Download complete
# 6c1698a608f3: Download complete
# 6cc007ad9140: Verifying Checksum
# 6cc007ad9140: Download complete
# a9c966eafa61: Verifying Checksum
# a9c966eafa61: Download complete
# a6c378d11cbf: Verifying Checksum
# a6c378d11cbf: Download complete
# 1460a62ff947: Download complete
# 0b4c4154ff8b: Verifying Checksum
# 0b4c4154ff8b: Download complete
# 333603dc44f9: Verifying Checksum
# bd12bd79bfb9: Download complete
# a1298f4ce990: Pull complete
# 04a3282d9c4b: Pull complete
# 9b0d3db6dc03: Pull complete
# 8269c605f3f1: Pull complete
# 6504d449e70c: Pull complete
# e8f479870769: Verifying Checksum
# e8f479870769: Download complete
# 4e38f320d0d4: Pull complete
# b0a763e8ee03: Pull complete
# 11917a028ca4: Pull complete
# a6c378d11cbf: Pull complete
# 6cc007ad9140: Pull complete
# 6c1698a608f3: Pull complete
# 1460a62ff947: Pull complete
# a9c966eafa61: Pull complete
# 0b4c4154ff8b: Pull complete
# 333603dc44f9: Pull complete
# e8f479870769: Pull complete
# bd12bd79bfb9: Pull complete
# Digest: sha256:ba8c032ab3170703276b11fed1c04ed13f9a5858f9ae0b8e710cb1429551f24e
# Status: Downloaded newer image for ancientriverd4d046d4.azurecr.io/azureml/azureml_2c6e63ed5158ba5dbcb9b13d72e8814a:latest
# 83f0df0bfe6cf67c30337352f31a2fffa0e5640bef34424467fa0ef3c21f08e3
# 2020/03/01 23:46:23 Version: 3.0.01140.0002 Branch: merge Commit: 93399ed1
# 2020/03/01 23:46:24 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/03/01 23:46:24 sshd runtime has already been installed in the container
# ssh-keygen: /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# ssh-keygen: /azureml-envs/azureml_9a530ceb888e99e194c82194b861d3dd/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
#
# Streaming azureml-logs/65_job_prep-tvmps_2a4a06821f6562f35440589203c0af982a1395217a9f15d07b9ef55f716c56e7_d.txt
# ===============================================================================================================
# Starting job preparation. Current time:2020-03-01T23:46:32.629020
# Extracting the control code.
# Creating directory: azureml-logs/
# Retrieving project from snapshot: b8db9a79-7399-4719-9567-4494da68125b
# Starting the daemon thread to refresh tokens in background for process with pid = 98
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# Starting the daemon thread to refresh tokens in background for process with pid = 158
# Entering Run History Context Manager.
# Preparing to call script [ ancient-rivers-scoring-script.py ] with arguments: ['--model-name', 'AutoML37a31f86512', '--scoring-directory', '/mnt/batch/tasks/shared/LS_root/jobs/ancient-rivers-ml-workspace/azureml/61a4cb8e-59c4-4fe1-8b55-b770560e3b7f/mounts/ancientrivers/test/scored', '--input-data', '/mnt/batch/tasks/shared/LS_root/jobs/ancient-rivers-ml-workspace/azureml/61a4cb8e-59c4-4fe1-8b55-b770560e3b7f/mounts/ancientrivers/test/landing/input']
# After variable expansion, calling script [ ancient-rivers-scoring-script.py ] with arguments: ['--model-name', 'AutoML37a31f86512', '--scoring-directory', '/mnt/batch/tasks/shared/LS_root/jobs/ancient-rivers-ml-workspace/azureml/61a4cb8e-59c4-4fe1-8b55-b770560e3b7f/mounts/ancientrivers/test/scored', '--input-data', '/mnt/batch/tasks/shared/LS_root/jobs/ancient-rivers-ml-workspace/azureml/61a4cb8e-59c4-4fe1-8b55-b770560e3b7f/mounts/ancientrivers/test/landing/input']
#
# ERROR - Importing plotly failed. Interactive plots will not work.
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 3 items cleaning up...
# Cleanup took 0.002802133560180664 seconds
# Starting the daemon thread to refresh tokens in background for process with pid = 158
#
# Streaming azureml-logs/75_job_post-tvmps_2a4a06821f6562f35440589203c0af982a1395217a9f15d07b9ef55f716c56e7_d.txt
# ===============================================================================================================
# Starting job release. Current time:2020-03-01T23:47:29.167470
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 258
# Job release is complete. Current time:2020-03-01T23:47:31.164262
#
# StepRun(ancient-rivers-scoring-step) Execution Summary
# =======================================================
# StepRun( ancient-rivers-scoring-step ) Status: Finished
# {'runId': '61a4cb8e-59c4-4fe1-8b55-b770560e3b7f', 'target': 'cpu-cluster-h', 'status': 'Completed', 'startTimeUtc': '2020-03-01T23:45:28.578467Z', 'endTimeUtc': '2020-03-01T23:47:45.692379Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'b8db9a79-7399-4719-9567-4494da68125b', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.pipelinerunid': '9c415af0-45fc-4c1a-9f7c-f60c717be6a3', '_azureml.ComputeTargetType': 'amlcompute', 'AzureML.DerivedImageName': 'azureml/azureml_2c6e63ed5158ba5dbcb9b13d72e8814a', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'ancient-rivers-scoring-script.py', 'useAbsolutePath': False, 'arguments': ['--model-name', 'AutoML37a31f86512', '--scoring-directory', '$AZUREML_DATAREFERENCE_ancient_rivers_scored_zone', '--input-data', '$AZUREML_DATAREFERENCE_ancient_rivers_landing_zone'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'cpu-cluster-h', 'dataReferences': {'ancient_rivers_landing_zone': {'dataStoreName': 'ancientrivers', 'mode': 'Mount', 'pathOnDataStore': 'test/landing/input', 'pathOnCompute': None, 'overwrite': False}, 'ancient_rivers_scored_zone': {'dataStoreName': 'ancientrivers', 'mode': 'Mount', 'pathOnDataStore': 'test/scored', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment ancient-rivers-scoring-pipeline Environment', 'version': 'Autosave_2020-03-01T23:29:05Z_c2448bd1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-train-automl-runtime==1.0.85.5', 'inference-schema', 'azureml-explain-model==1.0.85', 'azureml-defaults==1.0.85.1']}, 'py-xgboost==0.80', 'numpy==1.16.2', 'pandas==0.23.4', 'psutil==5.6.3', 'fbprophet==0.5', 'scikit-learn==0.20.3', 'joblib==0.14.1'], 'name': 'azureml_9a530ceb888e99e194c82194b861d3dd'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': ['[]'], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://ancientriversm8752540079.blob.core.windows.net/azureml/ExperimentRun/dcid.61a4cb8e-59c4-4fe1-8b55-b770560e3b7f/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=LqoixeAYSDBpSrFUASQPj52Rxfk4I8oIBMU2xlBuuoQ%3D&st=2020-03-01T23%3A37%3A53Z&se=2020-03-02T07%3A47%3A53Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_2a4a06821f6562f35440589203c0af982a1395217a9f15d07b9ef55f716c56e7_d.txt': 'https://ancientriversm8752540079.blob.core.windows.net/azureml/ExperimentRun/dcid.61a4cb8e-59c4-4fe1-8b55-b770560e3b7f/azureml-logs/55_azureml-execution-tvmps_2a4a06821f6562f35440589203c0af982a1395217a9f15d07b9ef55f716c56e7_d.txt?sv=2019-02-02&sr=b&sig=UxKsIXW7%2F1BlZAhq6TSkGaDtrDeqtOjmiUSn6EG7ArQ%3D&st=2020-03-01T23%3A37%3A53Z&se=2020-03-02T07%3A47%3A53Z&sp=r', 'azureml-logs/65_job_prep-tvmps_2a4a ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '9c415af0-45fc-4c1a-9f7c-f60c717be6a3', 'status': 'Completed', 'startTimeUtc': '2020-03-01T23:28:55.791528Z', 'endTimeUtc': '2020-03-01T23:47:52.02492Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://ancientriversm8752540079.blob.core.windows.net/azureml/ExperimentRun/dcid.9c415af0-45fc-4c1a-9f7c-f60c717be6a3/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=2Sm2AhOE5Bh29Ya05aa2ExIQfoyeAvpP4CEpqZPaqEQ%3D&st=2020-03-01T23%3A37%3A56Z&se=2020-03-02T07%3A47%3A56Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://ancientriversm8752540079.blob.core.windows.net/azureml/ExperimentRun/dcid.9c415af0-45fc-4c1a-9f7c-f60c717be6a3/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=%2Ft6IhAcQfgfGN2ZOIUvTSD7NSQx0MSwyVvR84dnXORM%3D&st=2020-03-01T23%3A37%3A56Z&se=2020-03-02T07%3A47%3A56Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://ancientriversm8752540079.blob.core.windows.net/azureml/ExperimentRun/dcid.9c415af0-45fc-4c1a-9f7c-f60c717be6a3/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=DIgf3I4wFgG6XnWDuxhbsdsVTME54Opg2nlIk9d%2FJDM%3D&st=2020-03-01T23%3A37%3A56Z&se=2020-03-02T07%3A47%3A56Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ### Publish your pipeline
# Once your pipeline is running, pubish it for later reuse.  When you publish a pipeline, you create a REST endpoint that you can use in Azure Data Factory.

# %%
# Match the name to your pipeline experiment
published_pipeline = pipeline_run.publish_pipeline(
    name="ancient-rivers-scoring-pipeline",\
    description="Ancient Rivers Scoring Batch Execution Pipeline for ADF Use", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: ancient-rivers-scoring-pipeline,
# Id: 2f6a87b0-bfcc-4f22-8190-8264589ab32b,
# Status: Active,
# Endpoint: https://eastus.aether.ms/api/v1.0/subscriptions/47a7ec0c-37ad-428b-9114-b87ea1057632/resourceGroups/xeek-ancient-rivers/providers/Microsoft.MachineLearningServices/workspaces/ancient-rivers-ml-workspace/PipelineRuns/PipelineSubmit/2f6a87b0-bfcc-4f22-8190-8264589ab32b)
